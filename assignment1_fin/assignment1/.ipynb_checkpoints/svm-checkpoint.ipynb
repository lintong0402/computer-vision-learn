# %% [markdown]
# # Multiclass Support Vector Machine exercise
#
# *Complete and hand in this completed worksheet (including its outputs and any supporting code outside of the worksheet) with your assignment submission. For more details see the [assignments page](http://vision.stanford.edu/teaching/cs231n/assignments.html) on the course website.*
#
# In this exercise you will:
#
# - implement a fully-vectorized **loss function** for the SVM
# - implement the fully-vectorized expression for its **analytic gradient**
# - **check your implementation** using numerical gradient
# - use a validation set to **tune the learning rate and regularization** strength
# - **optimize** the loss function with **SGD**
# - **visualize** the final learned weights

# %%
# Run some setup code for this notebook.

import random
import numpy as np
from cs231n.data_utils import load_CIFAR10
import matplotlib.pyplot as plt

from __future__ import print_function

# This is a bit of magic to make matplotlib figures appear inline in the
# notebook rather than in a new window.
# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# Some more magic so that the notebook will reload external python modules;
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## CIFAR-10 Data Loading and Preprocessing

# %%
# Load the raw CIFAR-10 data.
cifar10_dir = 'cs231n/datasets/cifar-10-batches-py'

# Cleaning up variables to prevent loading data multiple times (which may cause memory issue)
try:
   del X_train, y_train
   del X_test, y_test
   print('Clear previously loaded data.')
except:
   pass

X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)

# As a sanity check, we print out the size of the training and test data.
print('Training data shape: ', X_train.shape)
print('Training labels shape: ', y_train.shape)
print('Test data shape: ', X_test.shape)
print('Test labels shape: ', y_test.shape)
# Out:
# Training data shape:  (50000, 32, 32, 3)
# Training labels shape:  (50000,)
# Test data shape:  (10000, 32, 32, 3)
# Test labels shape:  (10000,)

# %%
# Visualize some examples from the dataset.
# We show a few examples of training images from each class.
classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
num_classes = len(classes)
samples_per_class = 7
for y, cls in enumerate(classes):
    idxs = np.flatnonzero(y_train == y)
    idxs = np.random.choice(idxs, samples_per_class, replace=False)
    for i, idx in enumerate(idxs):
        plt_idx = i * num_classes + y + 1
        plt.subplot(samples_per_class, num_classes, plt_idx)
        plt.imshow(X_train[idx].astype('uint8'))
        plt.axis('off')
        if i == 0:
            plt.title(cls)
plt.show()

# %%
# Split the data into train, val, and test sets. In addition we will
# create a small development set as a subset of the training data;
# we can use this for development so our code runs faster.
num_training = 49000
num_validation = 1000
num_test = 1000
num_dev = 500

# Our validation set will be num_validation points from the original
# training set.
mask = range(num_training, num_training + num_validation)
X_val = X_train[mask]
y_val = y_train[mask]

# Our training set will be the first num_train points from the original
# training set.
mask = range(num_training)
X_train = X_train[mask]
y_train = y_train[mask]

# We will also make a development set, which is a small subset of
# the training set.
mask = np.random.choice(num_training, num_dev, replace=False)
X_dev = X_train[mask]
y_dev = y_train[mask]

# We use the first num_test points of the original test set as our
# test set.
mask = range(num_test)
X_test = X_test[mask]
y_test = y_test[mask]

print('Train data shape: ', X_train.shape)
print('Train labels shape: ', y_train.shape)
print('Validation data shape: ', X_val.shape)
print('Validation labels shape: ', y_val.shape)
print('Test data shape: ', X_test.shape)
print('Test labels shape: ', y_test.shape)
# Out:
# Train data shape:  (49000, 32, 32, 3)
# Train labels shape:  (49000,)
# Validation data shape:  (1000, 32, 32, 3)
# Validation labels shape:  (1000,)
# Test data shape:  (1000, 32, 32, 3)
# Test labels shape:  (1000,)

# %%
# Preprocessing: reshape the image data into rows
X_train = np.reshape(X_train, (X_train.shape[0], -1))
X_val = np.reshape(X_val, (X_val.shape[0], -1))
X_test = np.reshape(X_test, (X_test.shape[0], -1))
X_dev = np.reshape(X_dev, (X_dev.shape[0], -1))

# As a sanity check, print out the shapes of the data
print('Training data shape: ', X_train.shape)
print('Validation data shape: ', X_val.shape)
print('Test data shape: ', X_test.shape)
print('dev data shape: ', X_dev.shape)
# Out:
# Training data shape:  (49000, 3072)
# Validation data shape:  (1000, 3072)
# Test data shape:  (1000, 3072)
# dev data shape:  (500, 3072)

# %%
# Preprocessing: subtract the mean image
# first: compute the image mean based on the training data
mean_image = np.mean(X_train, axis=0)
print(mean_image[:10]) # print a few of the elements
plt.figure(figsize=(4,4))
plt.imshow(mean_image.reshape((32,32,3)).astype('uint8')) # visualize the mean image
plt.show()
# Out:
# [130.64189796 135.98173469 132.47391837 130.05569388 135.34804082
#  131.75402041 130.96055102 136.14328571 132.47636735 131.48467347]

# %%
# second: subtract the mean image from train and test data
X_train -= mean_image
X_val -= mean_image
X_test -= mean_image
X_dev -= mean_image

# %%
# third: append the bias dimension of ones (i.e. bias trick) so that our SVM
# only has to worry about optimizing a single weight matrix W.
X_train = np.hstack([X_train, np.ones((X_train.shape[0], 1))])
X_val = np.hstack([X_val, np.ones((X_val.shape[0], 1))])
X_test = np.hstack([X_test, np.ones((X_test.shape[0], 1))])
X_dev = np.hstack([X_dev, np.ones((X_dev.shape[0], 1))])

print(X_train.shape, X_val.shape, X_test.shape, X_dev.shape)
# Out:
# (49000, 3073) (1000, 3073) (1000, 3073) (500, 3073)

# %% [markdown]
# ## SVM Classifier
#
# Your code for this section will all be written inside **cs231n/classifiers/linear_svm.py**.
#
# As you can see, we have prefilled the function `compute_loss_naive` which uses for loops to evaluate the multiclass SVM loss function.

# %%
# Evaluate the naive implementation of the loss we provided for you:
from cs231n.classifiers.linear_svm import svm_loss_naive
import time

# generate a random SVM weight matrix of small numbers
W = np.random.randn(3073, 10) * 0.0001 

loss, grad = svm_loss_naive(W, X_dev, y_dev, 0.000005)
print('loss: %f' % (loss, ))
# Out:
# loss: 9.179229

# %% [markdown]
# The `grad` returned from the function above is right now all zero. Derive and implement the gradient for the SVM cost function and implement it inline inside the function `svm_loss_naive`. You will find it helpful to interleave your new code inside the existing function.
#
# To check that you have correctly implemented the gradient correctly, you can numerically estimate the gradient of the loss function and compare the numeric estimate to the gradient that you computed. We have provided code that does this for you:

# %%
# Once you've implemented the gradient, recompute it with the code below
# and gradient check it with the function we provided for you

# Compute the loss and its gradient at W.
loss, grad = svm_loss_naive(W, X_dev, y_dev, 0.0)

# Numerically compute the gradient along several randomly chosen dimensions, and
# compare them with your analytically computed gradient. The numbers should match
# almost exactly along all dimensions.
from cs231n.gradient_check import grad_check_sparse
f = lambda w: svm_loss_naive(w, X_dev, y_dev, 0.0)[0]
grad_numerical = grad_check_sparse(f, W, grad)

# do the gradient check once again with regularization turned on
# you didn't forget the regularization gradient did you?
loss, grad = svm_loss_naive(W, X_dev, y_dev, 5e1)
f = lambda w: svm_loss_naive(w, X_dev, y_dev, 5e1)[0]
grad_numerical = grad_check_sparse(f, W, grad)
# Out:
# numerical: 10.918645 analytic: 10.918645, relative error: 1.324900e-11
# numerical: 3.766098 analytic: 3.766098, relative error: 3.477437e-11
# numerical: -11.763124 analytic: -11.763124, relative error: 2.672209e-12
# numerical: 11.411059 analytic: 11.411059, relative error: 1.151139e-11
# numerical: -4.517641 analytic: -4.517641, relative error: 7.918844e-11
# numerical: -24.887406 analytic: -24.887406, relative error: 3.214692e-12
# numerical: 2.038498 analytic: 2.038498, relative error: 1.233997e-10
# numerical: 4.629552 analytic: 4.629552, relative error: 4.822067e-11
# numerical: 5.927279 analytic: 5.927279, relative error: 2.471558e-12
# numerical: 8.624093 analytic: 8.624093, relative error: 2.417521e-11
# numerical: 7.645931 analytic: 7.645931, relative error: 4.176172e-11
# numerical: 39.326254 analytic: 39.326254, relative error: 3.870234e-12
# numerical: 2.459103 analytic: 2.459103, relative error: 7.063071e-11
# numerical: -10.295865 analytic: -10.295865, relative error: 5.435946e-11
# numerical: -56.129582 analytic: -56.129582, relative error: 3.451911e-12
# numerical: 12.051655 analytic: 12.051655, relative error: 1.569303e-11
# numerical: -10.331314 analytic: -10.331314, relative error: 3.261943e-12
# numerical: 4.216752 analytic: 4.216752, relative error: 8.185202e-11
# numerical: 1.086336 analytic: 1.086336, relative error: 1.555735e-10
# numerical: 2.018741 analytic: 2.018741, relative error: 8.112683e-11

# %% [markdown]
# ### Inline Question 1:
# It is possible that once in a while a dimension in the gradcheck will not match exactly. What could such a discrepancy be caused by? Is it a reason for concern? What is a simple example in one dimension where a gradient check could fail? How would change the margin affect of the frequency of this happening? *Hint: the SVM loss function is not strictly speaking differentiable*
#
# **Your Answer:** *fill this in.*

# %%
# Next implement the function svm_loss_vectorized; for now only compute the loss;
# we will implement the gradient in a moment.
tic = time.time()
loss_naive, grad_naive = svm_loss_naive(W, X_dev, y_dev, 0.000005)
toc = time.time()
print('Naive loss: %e computed in %fs' % (loss_naive, toc - tic))

from cs231n.classifiers.linear_svm import svm_loss_vectorized
tic = time.time()
loss_vectorized, _ = svm_loss_vectorized(W, X_dev, y_dev, 0.000005)
toc = time.time()
print('Vectorized loss: %e computed in %fs' % (loss_vectorized, toc - tic))

# The losses should match but your vectorized implementation should be much faster.
print('difference: %f' % (loss_naive - loss_vectorized))
# Out:
# Naive loss: 9.179229e+00 computed in 0.144330s
# Vectorized loss: 9.179229e+00 computed in 0.002360s
# difference: 0.000000

# %%
# Complete the implementation of svm_loss_vectorized, and compute the gradient
# of the loss function in a vectorized way.

# The naive implementation and the vectorized implementation should match, but
# the vectorized version should still be much faster.
tic = time.time()
_, grad_naive = svm_loss_naive(W, X_dev, y_dev, 0.000005)
toc = time.time()
print('Naive loss and gradient: computed in %fs' % (toc - tic))

tic = time.time()
_, grad_vectorized = svm_loss_vectorized(W, X_dev, y_dev, 0.000005)
toc = time.time()
print('Vectorized loss and gradient: computed in %fs' % (toc - tic))

# The loss is a single number, so it is easy to compare the values computed
# by the two implementations. The gradient on the other hand is a matrix, so
# we use the Frobenius norm to compare them.
difference = np.linalg.norm(grad_naive - grad_vectorized, ord='fro')
print('difference: %f' % difference)
# Out:
# Naive loss and gradient: computed in 0.085163s
# Vectorized loss and gradient: computed in 0.003996s
# difference: 0.000000

# %% [markdown]
# ### Stochastic Gradient Descent
#
# We now have vectorized and efficient expressions for the loss, the gradient and our gradient matches the numerical gradient. We are therefore ready to do SGD to minimize the loss.

# %%
# In the file linear_classifier.py, implement SGD in the function
# LinearClassifier.train() and then run it with the code below.
from cs231n.classifiers import LinearSVM
svm = LinearSVM()
tic = time.time()
loss_hist = svm.train(X_train, y_train, learning_rate=1e-7, reg=2.5e4,
                      num_iters=1500, verbose=True)
toc = time.time()
print('That took %fs' % (toc - tic))
# Out:
# iteration 0 / 1500: loss 412.932685
# iteration 100 / 1500: loss 244.769742
# iteration 200 / 1500: loss 148.862521
# iteration 300 / 1500: loss 90.797907
# iteration 400 / 1500: loss 57.298646
# iteration 500 / 1500: loss 36.355090
# iteration 600 / 1500: loss 23.583010
# iteration 700 / 1500: loss 15.869914
# iteration 800 / 1500: loss 11.957591
# iteration 900 / 1500: loss 8.974428
# iteration 1000 / 1500: loss 7.643145
# iteration 1100 / 1500: loss 6.378139
# iteration 1200 / 1500: loss 5.943947
# iteration 1300 / 1500: loss 5.621705
# iteration 1400 / 1500: loss 5.316653
# That took 4.127466s

# %%
# A useful debugging strategy is to plot the loss as a function of
# iteration number:
plt.plot(loss_hist)
plt.xlabel('Iteration number')
plt.ylabel('Loss value')
plt.show()

# %%
# Write the LinearSVM.predict function and evaluate the performance on both the
# training and validation set
y_train_pred = svm.predict(X_train)
print('training accuracy: %f' % (np.mean(y_train == y_train_pred), ))
y_val_pred = svm.predict(X_val)
print('validation accuracy: %f' % (np.mean(y_val == y_val_pred), ))
# Out:
# training accuracy: 0.380796
# validation accuracy: 0.380000

# %%
# Use the validation set to tune hyperparameters (regularization strength and
# learning rate). You should experiment with different ranges for the learning
# rates and regularization strengths; if you are careful you should be able to
# get a classification accuracy of about 0.4 on the validation set.
learning_rates = [1e-7,2e-7,2.5e-7,3e-7,4e-7,5e-7,6e-7,7e-7,8e-7,9e-7,1e-6]
regularization_strengths = [1e2,2e2,2.5e2,3e2,3.5e2,1e3,2e3,3e3,4e3,5e3]

# results is dictionary mapping tuples of the form
# (learning_rate, regularization_strength) to tuples of the form
# (training_accuracy, validation_accuracy). The accuracy is simply the fraction
# of data points that are correctly classified.
results = {}
best_val = -1   # The highest validation accuracy that we have seen so far.
best_svm = None # The LinearSVM object that achieved the highest validation rate.

################################################################################
# TODO:                                                                        #
# Write code that chooses the best hyperparameters by tuning on the validation #
# set. For each combination of hyperparameters, train a linear SVM on the      #
# training set, compute its accuracy on the training and validation sets, and  #
# store these numbers in the results dictionary. In addition, store the best   #
# validation accuracy in best_val and the LinearSVM object that achieves this  #
# accuracy in best_svm.                                                        #
#                                                                              #
# Hint: You should use a small value for num_iters as you develop your         #
# validation code so that the SVMs don't take much time to train; once you are #
# confident that your validation code works, you should rerun the validation   #
# code with a larger value for num_iters.                                      #
################################################################################
# Your code
num_iters=1500
legarning_length = len(learning_rates)
reg_length = len(regularization_strengths)
for i in range(legarning_length):
    for j in range(reg_length):
        svm = LinearSVM()
        learning_rate = learning_rates[i]
        reg = regularization_strengths[j]
        svm.train(X_train, y_train, learning_rate=learning_rate, reg=reg,
                      num_iters=num_iters, verbose=True)
        y_train_pred_t =  svm.predict(X_train)
        y_val_pred_t = svm.predict(X_val)
        training_accuracy = np.mean(y_train == y_train_pred_t)
        validation_accuracy = np.mean(y_val == y_val_pred_t)
        if best_val<validation_accuracy:
            best_val=validation_accuracy
            best_svm=svm
        results[(learning_rate,reg)]=(training_accuracy,validation_accuracy)
################################################################################
#                              END OF YOUR CODE                                #
################################################################################
    
# Print out results.
for lr, reg in sorted(results):
    train_accuracy, val_accuracy = results[(lr, reg)]
    print('lr %e reg %e train accuracy: %f val accuracy: %f' % (
                lr, reg, train_accuracy, val_accuracy))
    
print('best validation accuracy achieved during cross-validation: %f' % best_val)
# Out:
# iteration 0 / 1500: loss 22.691985
# iteration 100 / 1500: loss 13.758713
# iteration 200 / 1500: loss 10.960931
# iteration 300 / 1500: loss 10.301924
# iteration 400 / 1500: loss 10.125951
# iteration 500 / 1500: loss 9.166886
# iteration 600 / 1500: loss 8.536477
# iteration 700 / 1500: loss 9.113010
# iteration 800 / 1500: loss 8.840647
# iteration 900 / 1500: loss 8.407881
# iteration 1000 / 1500: loss 9.254034
# iteration 1100 / 1500: loss 7.813569
# iteration 1200 / 1500: loss 7.565405
# iteration 1300 / 1500: loss 7.476583
# iteration 1400 / 1500: loss 7.618285
# iteration 0 / 1500: loss 28.741994
# iteration 100 / 1500: loss 14.327699
# iteration 200 / 1500: loss 12.908040
# iteration 300 / 1500: loss 11.671860
# iteration 400 / 1500: loss 11.303743
# iteration 500 / 1500: loss 10.886257
# iteration 600 / 1500: loss 12.170670
# iteration 700 / 1500: loss 11.279935
# iteration 800 / 1500: loss 10.614982
# iteration 900 / 1500: loss 9.228815
# iteration 1000 / 1500: loss 9.305748
# iteration 1100 / 1500: loss 9.839187
# iteration 1200 / 1500: loss 9.152400
# iteration 1300 / 1500: loss 8.984938
# iteration 1400 / 1500: loss 8.895054
# iteration 0 / 1500: loss 26.610375
# iteration 100 / 1500: loss 14.375229
# iteration 200 / 1500: loss 12.675643
# iteration 300 / 1500: loss 11.465800
# iteration 400 / 1500: loss 11.884557
# iteration 500 / 1500: loss 10.985537
# iteration 600 / 1500: loss 10.290541
# iteration 700 / 1500: loss 9.649928
# iteration 800 / 1500: loss 10.840129
# iteration 900 / 1500: loss 10.836551
# iteration 1000 / 1500: loss 11.808840
# iteration 1100 / 1500: loss 9.923396
# iteration 1200 / 1500: loss 10.248672
# iteration 1300 / 1500: loss 9.266697
# iteration 1400 / 1500: loss 8.818501
# iteration 0 / 1500: loss 30.092025
# iteration 100 / 1500: loss 15.990018
# iteration 200 / 1500: loss 14.972885
# iteration 300 / 1500: loss 13.561941
# iteration 400 / 1500: loss 12.258861
# iteration 500 / 1500: loss 12.962584
# iteration 600 / 1500: loss 11.839682
# iteration 700 / 1500: loss 11.315572
# iteration 800 / 1500: loss 12.551745
# iteration 900 / 1500: loss 10.721363
# iteration 1000 / 1500: loss 9.815077
# iteration 1100 / 1500: loss 10.735792
# iteration 1200 / 1500: loss 11.119447
# iteration 1300 / 1500: loss 8.895433
# iteration 1400 / 1500: loss 10.268434
# iteration 0 / 1500: loss 26.945487
# iteration 100 / 1500: loss 14.778792
# iteration 200 / 1500: loss 13.549534
# iteration 300 / 1500: loss 13.941537
# iteration 400 / 1500: loss 12.990162
# iteration 500 / 1500: loss 13.096317
# iteration 600 / 1500: loss 12.880927
# iteration 700 / 1500: loss 12.025566
# iteration 800 / 1500: loss 11.705021
# iteration 900 / 1500: loss 11.396396
# iteration 1000 / 1500: loss 10.809068
# iteration 1100 / 1500: loss 12.204026
# iteration 1200 / 1500: loss 11.025957
# iteration 1300 / 1500: loss 11.797029
# iteration 1400 / 1500: loss 11.340482
# iteration 0 / 1500: loss 42.330801
# iteration 100 / 1500: loss 26.604352
# iteration 200 / 1500: loss 23.537979
# iteration 300 / 1500: loss 22.524331
# iteration 400 / 1500: loss 21.313033
# iteration 500 / 1500: loss 21.533206
# iteration 600 / 1500: loss 20.026266
# iteration 700 / 1500: loss 20.162124
# iteration 800 / 1500: loss 19.137661
# iteration 900 / 1500: loss 19.155686
# iteration 1000 / 1500: loss 18.858763
# iteration 1100 / 1500: loss 18.771982
# iteration 1200 / 1500: loss 18.455767
# iteration 1300 / 1500: loss 18.039448
# iteration 1400 / 1500: loss 17.406668
# iteration 0 / 1500: loss 55.644645
# iteration 100 / 1500: loss 40.743397
# iteration 200 / 1500: loss 38.515666
# iteration 300 / 1500: loss 35.460644
# iteration 400 / 1500: loss 33.417445
# iteration 500 / 1500: loss 32.390831
# iteration 600 / 1500: loss 31.709624
# iteration 700 / 1500: loss 29.097166
# iteration 800 / 1500: loss 28.354182
# iteration 900 / 1500: loss 27.464491
# iteration 1000 / 1500: loss 27.001128
# iteration 1100 / 1500: loss 25.694088
# iteration 1200 / 1500: loss 24.495669
# iteration 1300 / 1500: loss 23.852525
# iteration 1400 / 1500: loss 22.745454
# iteration 0 / 1500: loss 65.961359
# iteration 100 / 1500: loss 53.710461
# iteration 200 / 1500: loss 50.472962
# iteration 300 / 1500: loss 46.903000
# iteration 400 / 1500: loss 43.110990
# iteration 500 / 1500: loss 39.196876
# iteration 600 / 1500: loss 39.162723
# iteration 700 / 1500: loss 36.458165
# iteration 800 / 1500: loss 34.843801
# iteration 900 / 1500: loss 31.690338
# iteration 1000 / 1500: loss 29.957218
# iteration 1100 / 1500: loss 28.447910
# iteration 1200 / 1500: loss 27.056025
# iteration 1300 / 1500: loss 25.501197
# iteration 1400 / 1500: loss 24.570295
# iteration 0 / 1500: loss 87.248290
# iteration 100 / 1500: loss 67.534036
# iteration 200 / 1500: loss 61.394954
# iteration 300 / 1500: loss 55.451988
# iteration 400 / 1500: loss 50.037615
# iteration 500 / 1500: loss 46.935811
# iteration 600 / 1500: loss 43.724027
# iteration 700 / 1500: loss 40.880881
# iteration 800 / 1500: loss 37.903570
# iteration 900 / 1500: loss 35.090806
# iteration 1000 / 1500: loss 32.637996
# iteration 1100 / 1500: loss 31.804526
# iteration 1200 / 1500: loss 27.607940
# iteration 1300 / 1500: loss 26.478822
# iteration 1400 / 1500: loss 24.855985
# iteration 0 / 1500: loss 101.493097
# iteration 100 / 1500: loss 81.257884
# iteration 200 / 1500: loss 71.027358
# iteration 300 / 1500: loss 64.031325
# iteration 400 / 1500: loss 58.550356
# iteration 500 / 1500: loss 52.175477
# iteration 600 / 1500: loss 47.566943
# iteration 700 / 1500: loss 44.346343
# iteration 800 / 1500: loss 40.137706
# iteration 900 / 1500: loss 35.874306
# iteration 1000 / 1500: loss 32.524593
# iteration 1100 / 1500: loss 30.645612
# iteration 1200 / 1500: loss 27.918833
# iteration 1300 / 1500: loss 25.404394
# iteration 1400 / 1500: loss 22.971835
# iteration 0 / 1500: loss 26.986215
# iteration 100 / 1500: loss 10.723164
# iteration 200 / 1500: loss 9.823476
# iteration 300 / 1500: loss 9.357543
# iteration 400 / 1500: loss 8.466890
# iteration 500 / 1500: loss 7.584216
# iteration 600 / 1500: loss 8.409078
# iteration 700 / 1500: loss 8.929870
# iteration 800 / 1500: loss 8.619408
# iteration 900 / 1500: loss 7.953338
# iteration 1000 / 1500: loss 8.116399
# iteration 1100 / 1500: loss 7.197789
# iteration 1200 / 1500: loss 6.341730
# iteration 1300 / 1500: loss 7.164192
# iteration 1400 / 1500: loss 7.448796
# iteration 0 / 1500: loss 23.274137
# iteration 100 / 1500: loss 11.977262
# iteration 200 / 1500: loss 10.863453
# iteration 300 / 1500: loss 11.017711
# iteration 400 / 1500: loss 9.431673
# iteration 500 / 1500: loss 10.213592
# iteration 600 / 1500: loss 8.985030
# iteration 700 / 1500: loss 9.148329
# iteration 800 / 1500: loss 9.136178
# iteration 900 / 1500: loss 9.000867
# iteration 1000 / 1500: loss 9.049383
# iteration 1100 / 1500: loss 8.415784
# iteration 1200 / 1500: loss 8.345050
# iteration 1300 / 1500: loss 8.020164
# iteration 1400 / 1500: loss 8.295014
# iteration 0 / 1500: loss 21.041607
# iteration 100 / 1500: loss 12.689151
# iteration 200 / 1500: loss 13.563670
# iteration 300 / 1500: loss 10.506612
# iteration 400 / 1500: loss 11.781232
# iteration 500 / 1500: loss 10.382452
# iteration 600 / 1500: loss 10.215398
# iteration 700 / 1500: loss 9.993424
# iteration 800 / 1500: loss 9.647496
# iteration 900 / 1500: loss 9.858337
# iteration 1000 / 1500: loss 9.925581
# iteration 1100 / 1500: loss 8.873744
# iteration 1200 / 1500: loss 10.150955
# iteration 1300 / 1500: loss 9.113436
# iteration 1400 / 1500: loss 8.794599
# iteration 0 / 1500: loss 30.450875
# iteration 100 / 1500: loss 12.598915
# iteration 200 / 1500: loss 13.552254
# iteration 300 / 1500: loss 11.363574
# iteration 400 / 1500: loss 11.564200
# iteration 500 / 1500: loss 11.526193
# iteration 600 / 1500: loss 10.326108
# iteration 700 / 1500: loss 10.212310
# iteration 800 / 1500: loss 11.055649
# iteration 900 / 1500: loss 10.534139
# iteration 1000 / 1500: loss 10.310125
# iteration 1100 / 1500: loss 9.343766
# iteration 1200 / 1500: loss 9.685653
# iteration 1300 / 1500: loss 10.321093
# iteration 1400 / 1500: loss 9.249663
# iteration 0 / 1500: loss 25.489999
# iteration 100 / 1500: loss 14.699667
# iteration 200 / 1500: loss 13.067025
# iteration 300 / 1500: loss 12.854191
# iteration 400 / 1500: loss 12.875451
# iteration 500 / 1500: loss 11.117691
# iteration 600 / 1500: loss 9.641544
# iteration 700 / 1500: loss 10.146383
# iteration 800 / 1500: loss 10.662882
# iteration 900 / 1500: loss 10.419742
# iteration 1000 / 1500: loss 10.559950
# iteration 1100 / 1500: loss 10.661880
# iteration 1200 / 1500: loss 10.320336
# iteration 1300 / 1500: loss 9.422835
# iteration 1400 / 1500: loss 9.349184
# iteration 0 / 1500: loss 40.271901
# iteration 100 / 1500: loss 24.317183
# iteration 200 / 1500: loss 20.605483
# iteration 300 / 1500: loss 20.785164
# iteration 400 / 1500: loss 19.168475
# iteration 500 / 1500: loss 18.666983
# iteration 600 / 1500: loss 18.070118
# iteration 700 / 1500: loss 17.278606
# iteration 800 / 1500: loss 17.285708
# iteration 900 / 1500: loss 15.500707
# iteration 1000 / 1500: loss 15.001021
# iteration 1100 / 1500: loss 14.863556
# iteration 1200 / 1500: loss 14.175181
# iteration 1300 / 1500: loss 13.002742
# iteration 1400 / 1500: loss 13.186570
# iteration 0 / 1500: loss 57.026313
# iteration 100 / 1500: loss 37.725411
# iteration 200 / 1500: loss 34.055140
# iteration 300 / 1500: loss 30.509242
# iteration 400 / 1500: loss 29.030153
# iteration 500 / 1500: loss 26.187958
# iteration 600 / 1500: loss 24.978929
# iteration 700 / 1500: loss 23.218308
# iteration 800 / 1500: loss 20.980390
# iteration 900 / 1500: loss 19.663340
# iteration 1000 / 1500: loss 18.516910
# iteration 1100 / 1500: loss 17.056209
# iteration 1200 / 1500: loss 15.888110
# iteration 1300 / 1500: loss 14.879368
# iteration 1400 / 1500: loss 14.711662
# iteration 0 / 1500: loss 67.696133
# iteration 100 / 1500: loss 49.948254
# iteration 200 / 1500: loss 42.953459
# iteration 300 / 1500: loss 38.959856
# iteration 400 / 1500: loss 33.717853
# iteration 500 / 1500: loss 30.810096
# iteration 600 / 1500: loss 26.728538
# iteration 700 / 1500: loss 24.846763
# iteration 800 / 1500: loss 22.590772
# iteration 900 / 1500: loss 19.529979
# iteration 1000 / 1500: loss 17.256546
# iteration 1100 / 1500: loss 16.545592
# iteration 1200 / 1500: loss 15.204080
# iteration 1300 / 1500: loss 13.075639
# iteration 1400 / 1500: loss 12.869676
# iteration 0 / 1500: loss 83.105590
# iteration 100 / 1500: loss 61.058694
# iteration 200 / 1500: loss 51.232994
# iteration 300 / 1500: loss 43.651956
# iteration 400 / 1500: loss 37.487742
# iteration 500 / 1500: loss 31.976868
# iteration 600 / 1500: loss 28.724023
# iteration 700 / 1500: loss 23.880267
# iteration 800 / 1500: loss 21.384512
# iteration 900 / 1500: loss 18.478254
# iteration 1000 / 1500: loss 16.668697
# iteration 1100 / 1500: loss 14.854958
# iteration 1200 / 1500: loss 13.417984
# iteration 1300 / 1500: loss 12.259934
# iteration 1400 / 1500: loss 11.175444
# iteration 0 / 1500: loss 99.661295
# iteration 100 / 1500: loss 73.063055
# iteration 200 / 1500: loss 57.653589
# iteration 300 / 1500: loss 48.784498
# iteration 400 / 1500: loss 39.473322
# iteration 500 / 1500: loss 33.187332
# iteration 600 / 1500: loss 27.475505
# iteration 700 / 1500: loss 23.559422
# iteration 800 / 1500: loss 19.519717
# iteration 900 / 1500: loss 16.680888
# iteration 1000 / 1500: loss 14.833129
# iteration 1100 / 1500: loss 12.827788
# iteration 1200 / 1500: loss 10.224627
# iteration 1300 / 1500: loss 9.788089
# iteration 1400 / 1500: loss 9.230182
# iteration 0 / 1500: loss 24.638523
# iteration 100 / 1500: loss 12.360614
# iteration 200 / 1500: loss 9.524272
# iteration 300 / 1500: loss 9.862251
# iteration 400 / 1500: loss 8.001097
# iteration 500 / 1500: loss 7.531538
# iteration 600 / 1500: loss 7.785821
# iteration 700 / 1500: loss 7.286981
# iteration 800 / 1500: loss 8.069307
# iteration 900 / 1500: loss 7.608574
# iteration 1000 / 1500: loss 7.670086
# iteration 1100 / 1500: loss 7.478790
# iteration 1200 / 1500: loss 6.845029
# iteration 1300 / 1500: loss 7.707619
# iteration 1400 / 1500: loss 6.488421
# iteration 0 / 1500: loss 26.599819
# iteration 100 / 1500: loss 12.439351
# iteration 200 / 1500: loss 10.300034
# iteration 300 / 1500: loss 9.628676
# iteration 400 / 1500: loss 9.838406
# iteration 500 / 1500: loss 9.976885
# iteration 600 / 1500: loss 9.262917
# iteration 700 / 1500: loss 8.835629
# iteration 800 / 1500: loss 8.224341
# iteration 900 / 1500: loss 8.257253
# iteration 1000 / 1500: loss 8.602947
# iteration 1100 / 1500: loss 7.531334
# iteration 1200 / 1500: loss 8.660445
# iteration 1300 / 1500: loss 7.786985
# iteration 1400 / 1500: loss 8.617460
# iteration 0 / 1500: loss 22.351302
# iteration 100 / 1500: loss 12.665759
# iteration 200 / 1500: loss 9.829677
# iteration 300 / 1500: loss 11.103687
# iteration 400 / 1500: loss 10.082854
# iteration 500 / 1500: loss 10.785193
# iteration 600 / 1500: loss 9.948805
# iteration 700 / 1500: loss 9.286691
# iteration 800 / 1500: loss 10.714790
# iteration 900 / 1500: loss 9.159226
# iteration 1000 / 1500: loss 8.543504
# iteration 1100 / 1500: loss 9.251802
# iteration 1200 / 1500: loss 8.359090
# iteration 1300 / 1500: loss 9.344427
# iteration 1400 / 1500: loss 7.853846
# iteration 0 / 1500: loss 29.291734
# iteration 100 / 1500: loss 12.667556
# iteration 200 / 1500: loss 12.200218
# iteration 300 / 1500: loss 11.462345
# iteration 400 / 1500: loss 10.361602
# iteration 500 / 1500: loss 9.574827
# iteration 600 / 1500: loss 11.507309
# iteration 700 / 1500: loss 10.446064
# iteration 800 / 1500: loss 10.356937
# iteration 900 / 1500: loss 9.737478
# iteration 1000 / 1500: loss 8.505671
# iteration 1100 / 1500: loss 9.317681
# iteration 1200 / 1500: loss 8.819704
# iteration 1300 / 1500: loss 9.185615
# iteration 1400 / 1500: loss 8.575006
# iteration 0 / 1500: loss 23.967762
# iteration 100 / 1500: loss 14.215715
# iteration 200 / 1500: loss 12.805254
# iteration 300 / 1500: loss 12.842337
# iteration 400 / 1500: loss 11.995079
# iteration 500 / 1500: loss 11.846013
# iteration 600 / 1500: loss 10.420238
# iteration 700 / 1500: loss 10.556051
# iteration 800 / 1500: loss 10.425021
# iteration 900 / 1500: loss 9.505037
# iteration 1000 / 1500: loss 10.197790
# iteration 1100 / 1500: loss 10.245564
# iteration 1200 / 1500: loss 9.237804
# iteration 1300 / 1500: loss 9.921617
# iteration 1400 / 1500: loss 8.598682
# iteration 0 / 1500: loss 35.729330
# iteration 100 / 1500: loss 23.471390
# iteration 200 / 1500: loss 21.203511
# iteration 300 / 1500: loss 20.531519
# iteration 400 / 1500: loss 18.468829
# iteration 500 / 1500: loss 17.264041
# iteration 600 / 1500: loss 16.641537
# iteration 700 / 1500: loss 16.014634
# iteration 800 / 1500: loss 14.598923
# iteration 900 / 1500: loss 15.355540
# iteration 1000 / 1500: loss 13.803308
# iteration 1100 / 1500: loss 13.775476
# iteration 1200 / 1500: loss 13.387580
# iteration 1300 / 1500: loss 12.094695
# iteration 1400 / 1500: loss 13.069403
# iteration 0 / 1500: loss 52.267021
# iteration 100 / 1500: loss 35.740594
# iteration 200 / 1500: loss 30.949933
# iteration 300 / 1500: loss 28.763185
# iteration 400 / 1500: loss 26.612345
# iteration 500 / 1500: loss 23.463465
# iteration 600 / 1500: loss 21.947565
# iteration 700 / 1500: loss 19.331517
# iteration 800 / 1500: loss 18.678012
# iteration 900 / 1500: loss 16.831538
# iteration 1000 / 1500: loss 15.340238
# iteration 1100 / 1500: loss 14.512125
# iteration 1200 / 1500: loss 14.601760
# iteration 1300 / 1500: loss 11.985540
# iteration 1400 / 1500: loss 11.395069
# iteration 0 / 1500: loss 67.762022
# iteration 100 / 1500: loss 47.821755
# iteration 200 / 1500: loss 40.918923
# iteration 300 / 1500: loss 34.490544
# iteration 400 / 1500: loss 30.400565
# iteration 500 / 1500: loss 26.235924
# iteration 600 / 1500: loss 23.138539
# iteration 700 / 1500: loss 20.294146
# iteration 800 / 1500: loss 18.203893
# iteration 900 / 1500: loss 17.276211
# iteration 1000 / 1500: loss 14.354685
# iteration 1100 / 1500: loss 13.864275
# iteration 1200 / 1500: loss 11.914814
# iteration 1300 / 1500: loss 10.362174
# iteration 1400 / 1500: loss 9.981334
# iteration 0 / 1500: loss 84.392980
# iteration 100 / 1500: loss 58.182885
# iteration 200 / 1500: loss 47.558292
# iteration 300 / 1500: loss 38.348239
# iteration 400 / 1500: loss 32.318636
# iteration 500 / 1500: loss 26.849590
# iteration 600 / 1500: loss 22.884823
# iteration 700 / 1500: loss 19.704614
# iteration 800 / 1500: loss 16.493203
# iteration 900 / 1500: loss 14.989870
# iteration 1000 / 1500: loss 12.754706
# iteration 1100 / 1500: loss 10.751493
# iteration 1200 / 1500: loss 9.668513
# iteration 1300 / 1500: loss 9.123402
# iteration 1400 / 1500: loss 7.901859
# iteration 0 / 1500: loss 96.993739
# iteration 100 / 1500: loss 66.080447
# iteration 200 / 1500: loss 51.720272
# iteration 300 / 1500: loss 41.374995
# iteration 400 / 1500: loss 32.673875
# iteration 500 / 1500: loss 26.267568
# iteration 600 / 1500: loss 21.073013
# iteration 700 / 1500: loss 18.214764
# iteration 800 / 1500: loss 14.929074
# iteration 900 / 1500: loss 12.269443
# iteration 1000 / 1500: loss 10.086300
# iteration 1100 / 1500: loss 9.239443
# iteration 1200 / 1500: loss 8.557069
# iteration 1300 / 1500: loss 7.400506
# iteration 1400 / 1500: loss 6.929713
# iteration 0 / 1500: loss 21.202488
# iteration 100 / 1500: loss 10.285039
# iteration 200 / 1500: loss 9.314035
# iteration 300 / 1500: loss 7.858737
# iteration 400 / 1500: loss 9.556812
# iteration 500 / 1500: loss 8.297450
# iteration 600 / 1500: loss 8.089576
# iteration 700 / 1500: loss 7.392425
# iteration 800 / 1500: loss 7.010456
# iteration 900 / 1500: loss 6.686701
# iteration 1000 / 1500: loss 6.783112
# iteration 1100 / 1500: loss 6.792397
# iteration 1200 / 1500: loss 6.666303
# iteration 1300 / 1500: loss 7.266049
# iteration 1400 / 1500: loss 6.865135
# iteration 0 / 1500: loss 25.015416
# iteration 100 / 1500: loss 11.732919
# iteration 200 / 1500: loss 9.703850
# iteration 300 / 1500: loss 11.095097
# iteration 400 / 1500: loss 9.941756
# iteration 500 / 1500: loss 8.521439
# iteration 600 / 1500: loss 9.750924
# iteration 700 / 1500: loss 8.713705
# iteration 800 / 1500: loss 8.090813
# iteration 900 / 1500: loss 8.474047
# iteration 1000 / 1500: loss 8.415082
# iteration 1100 / 1500: loss 8.826956
# iteration 1200 / 1500: loss 8.041698
# iteration 1300 / 1500: loss 8.194444
# iteration 1400 / 1500: loss 8.222030
# iteration 0 / 1500: loss 29.178894
# iteration 100 / 1500: loss 11.946446
# iteration 200 / 1500: loss 11.894273
# iteration 300 / 1500: loss 10.399786
# iteration 400 / 1500: loss 9.374869
# iteration 500 / 1500: loss 8.660612
# iteration 600 / 1500: loss 10.495148
# iteration 700 / 1500: loss 8.493191
# iteration 800 / 1500: loss 8.473566
# iteration 900 / 1500: loss 8.854562
# iteration 1000 / 1500: loss 8.211552
# iteration 1100 / 1500: loss 7.718853
# iteration 1200 / 1500: loss 8.327712
# iteration 1300 / 1500: loss 8.005266
# iteration 1400 / 1500: loss 8.059149
# iteration 0 / 1500: loss 31.361790
# iteration 100 / 1500: loss 13.797077
# iteration 200 / 1500: loss 12.114321
# iteration 300 / 1500: loss 11.014686
# iteration 400 / 1500: loss 11.790207
# iteration 500 / 1500: loss 10.473735
# iteration 600 / 1500: loss 9.626234
# iteration 700 / 1500: loss 10.716602
# iteration 800 / 1500: loss 8.990520
# iteration 900 / 1500: loss 9.650449
# iteration 1000 / 1500: loss 8.819268
# iteration 1100 / 1500: loss 9.398927
# iteration 1200 / 1500: loss 9.352968
# iteration 1300 / 1500: loss 8.301995
# iteration 1400 / 1500: loss 8.731169
# iteration 0 / 1500: loss 23.928248
# iteration 100 / 1500: loss 13.730382
# iteration 200 / 1500: loss 12.132256
# iteration 300 / 1500: loss 12.802024
# iteration 400 / 1500: loss 10.377107
# iteration 500 / 1500: loss 11.565481
# iteration 600 / 1500: loss 10.443824
# iteration 700 / 1500: loss 10.810418
# iteration 800 / 1500: loss 10.248218
# iteration 900 / 1500: loss 9.757371
# iteration 1000 / 1500: loss 9.772872
# iteration 1100 / 1500: loss 9.058941
# iteration 1200 / 1500: loss 8.883898
# iteration 1300 / 1500: loss 8.989472
# iteration 1400 / 1500: loss 8.629747
# iteration 0 / 1500: loss 37.946613
# iteration 100 / 1500: loss 21.805992
# iteration 200 / 1500: loss 20.271332
# iteration 300 / 1500: loss 18.462787
# iteration 400 / 1500: loss 18.786087
# iteration 500 / 1500: loss 15.822148
# iteration 600 / 1500: loss 16.096698
# iteration 700 / 1500: loss 16.374156
# iteration 800 / 1500: loss 13.938998
# iteration 900 / 1500: loss 14.087041
# iteration 1000 / 1500: loss 13.213425
# iteration 1100 / 1500: loss 12.591675
# iteration 1200 / 1500: loss 11.904016
# iteration 1300 / 1500: loss 11.950562
# iteration 1400 / 1500: loss 10.824652
# iteration 0 / 1500: loss 51.715322
# iteration 100 / 1500: loss 36.497648
# iteration 200 / 1500: loss 31.094292
# iteration 300 / 1500: loss 26.524734
# iteration 400 / 1500: loss 25.046594
# iteration 500 / 1500: loss 21.053790
# iteration 600 / 1500: loss 19.848500
# iteration 700 / 1500: loss 17.953095
# iteration 800 / 1500: loss 16.277033
# iteration 900 / 1500: loss 14.898685
# iteration 1000 / 1500: loss 13.143975
# iteration 1100 / 1500: loss 12.786354
# iteration 1200 / 1500: loss 11.885432
# iteration 1300 / 1500: loss 10.088249
# iteration 1400 / 1500: loss 9.654478
# iteration 0 / 1500: loss 69.725962
# iteration 100 / 1500: loss 44.704945
# iteration 200 / 1500: loss 37.755431
# iteration 300 / 1500: loss 32.301436
# iteration 400 / 1500: loss 26.890086
# iteration 500 / 1500: loss 22.437666
# iteration 600 / 1500: loss 19.652228
# iteration 700 / 1500: loss 17.597043
# iteration 800 / 1500: loss 14.947877
# iteration 900 / 1500: loss 13.855994
# iteration 1000 / 1500: loss 11.181393
# iteration 1100 / 1500: loss 10.597949
# iteration 1200 / 1500: loss 9.729365
# iteration 1300 / 1500: loss 8.373912
# iteration 1400 / 1500: loss 7.446892
# iteration 0 / 1500: loss 80.558154
# iteration 100 / 1500: loss 54.052973
# iteration 200 / 1500: loss 43.665539
# iteration 300 / 1500: loss 33.747557
# iteration 400 / 1500: loss 28.005033
# iteration 500 / 1500: loss 22.290548
# iteration 600 / 1500: loss 18.493257
# iteration 700 / 1500: loss 15.559093
# iteration 800 / 1500: loss 13.812179
# iteration 900 / 1500: loss 10.761457
# iteration 1000 / 1500: loss 9.751562
# iteration 1100 / 1500: loss 8.989390
# iteration 1200 / 1500: loss 7.583000
# iteration 1300 / 1500: loss 7.151839
# iteration 1400 / 1500: loss 6.288422
# iteration 0 / 1500: loss 100.403282
# iteration 100 / 1500: loss 64.094614
# iteration 200 / 1500: loss 47.799620
# iteration 300 / 1500: loss 36.558299
# iteration 400 / 1500: loss 27.449377
# iteration 500 / 1500: loss 21.831633
# iteration 600 / 1500: loss 16.659165
# iteration 700 / 1500: loss 13.956740
# iteration 800 / 1500: loss 10.988760
# iteration 900 / 1500: loss 9.810334
# iteration 1000 / 1500: loss 8.631250
# iteration 1100 / 1500: loss 7.535912
# iteration 1200 / 1500: loss 6.280212
# iteration 1300 / 1500: loss 6.581615
# iteration 1400 / 1500: loss 5.699728
# iteration 0 / 1500: loss 28.472726
# iteration 100 / 1500: loss 10.534645
# iteration 200 / 1500: loss 9.043118
# iteration 300 / 1500: loss 9.667172
# iteration 400 / 1500: loss 8.173426
# iteration 500 / 1500: loss 8.277483
# iteration 600 / 1500: loss 7.129766
# iteration 700 / 1500: loss 7.117763
# iteration 800 / 1500: loss 6.882654
# iteration 900 / 1500: loss 6.115504
# iteration 1000 / 1500: loss 6.521856
# iteration 1100 / 1500: loss 6.255175
# iteration 1200 / 1500: loss 6.722930
# iteration 1300 / 1500: loss 6.211550
# iteration 1400 / 1500: loss 5.625818
# iteration 0 / 1500: loss 23.155704
# iteration 100 / 1500: loss 11.714367
# iteration 200 / 1500: loss 9.379032
# iteration 300 / 1500: loss 9.497300
# iteration 400 / 1500: loss 7.950493
# iteration 500 / 1500: loss 9.461023
# iteration 600 / 1500: loss 7.691846
# iteration 700 / 1500: loss 8.921374
# iteration 800 / 1500: loss 8.713579
# iteration 900 / 1500: loss 7.527900
# iteration 1000 / 1500: loss 7.475500
# iteration 1100 / 1500: loss 7.587727
# iteration 1200 / 1500: loss 7.514760
# iteration 1300 / 1500: loss 7.641567
# iteration 1400 / 1500: loss 7.072075
# iteration 0 / 1500: loss 28.686452
# iteration 100 / 1500: loss 12.342534
# iteration 200 / 1500: loss 8.823739
# iteration 300 / 1500: loss 10.740022
# iteration 400 / 1500: loss 10.204165
# iteration 500 / 1500: loss 10.074128
# iteration 600 / 1500: loss 9.252909
# iteration 700 / 1500: loss 8.576285
# iteration 800 / 1500: loss 8.760772
# iteration 900 / 1500: loss 7.872190
# iteration 1000 / 1500: loss 7.280815
# iteration 1100 / 1500: loss 8.199902
# iteration 1200 / 1500: loss 7.699892
# iteration 1300 / 1500: loss 8.656197
# iteration 1400 / 1500: loss 6.588563
# iteration 0 / 1500: loss 25.759830
# iteration 100 / 1500: loss 12.018130
# iteration 200 / 1500: loss 11.829107
# iteration 300 / 1500: loss 11.069329
# iteration 400 / 1500: loss 9.666584
# iteration 500 / 1500: loss 9.899410
# iteration 600 / 1500: loss 9.711211
# iteration 700 / 1500: loss 9.122543
# iteration 800 / 1500: loss 9.241479
# iteration 900 / 1500: loss 9.242047
# iteration 1000 / 1500: loss 8.905302
# iteration 1100 / 1500: loss 7.988030
# iteration 1200 / 1500: loss 7.987052
# iteration 1300 / 1500: loss 8.110555
# iteration 1400 / 1500: loss 7.409482
# iteration 0 / 1500: loss 24.745419
# iteration 100 / 1500: loss 12.687411
# iteration 200 / 1500: loss 11.625016
# iteration 300 / 1500: loss 11.288089
# iteration 400 / 1500: loss 11.580635
# iteration 500 / 1500: loss 10.329982
# iteration 600 / 1500: loss 9.719431
# iteration 700 / 1500: loss 10.056582
# iteration 800 / 1500: loss 9.975078
# iteration 900 / 1500: loss 9.126060
# iteration 1000 / 1500: loss 8.641739
# iteration 1100 / 1500: loss 8.606309
# iteration 1200 / 1500: loss 8.768695
# iteration 1300 / 1500: loss 8.308777
# iteration 1400 / 1500: loss 7.883094
# iteration 0 / 1500: loss 39.294883
# iteration 100 / 1500: loss 20.914024
# iteration 200 / 1500: loss 19.834269
# iteration 300 / 1500: loss 18.070007
# iteration 400 / 1500: loss 17.049421
# iteration 500 / 1500: loss 15.191339
# iteration 600 / 1500: loss 13.989624
# iteration 700 / 1500: loss 13.757938
# iteration 800 / 1500: loss 13.068226
# iteration 900 / 1500: loss 11.417942
# iteration 1000 / 1500: loss 11.017203
# iteration 1100 / 1500: loss 11.079973
# iteration 1200 / 1500: loss 11.012220
# iteration 1300 / 1500: loss 9.179336
# iteration 1400 / 1500: loss 9.267817
# iteration 0 / 1500: loss 55.074867
# iteration 100 / 1500: loss 34.461054
# iteration 200 / 1500: loss 27.766985
# iteration 300 / 1500: loss 24.435704
# iteration 400 / 1500: loss 21.062847
# iteration 500 / 1500: loss 18.655757
# iteration 600 / 1500: loss 16.320212
# iteration 700 / 1500: loss 14.471453
# iteration 800 / 1500: loss 13.627769
# iteration 900 / 1500: loss 11.438144
# iteration 1000 / 1500: loss 10.342931
# iteration 1100 / 1500: loss 9.554927
# iteration 1200 / 1500: loss 8.534927
# iteration 1300 / 1500: loss 7.414570
# iteration 1400 / 1500: loss 7.156811
# iteration 0 / 1500: loss 64.963422
# iteration 100 / 1500: loss 43.878453
# iteration 200 / 1500: loss 35.279096
# iteration 300 / 1500: loss 27.305756
# iteration 400 / 1500: loss 23.235213
# iteration 500 / 1500: loss 18.150554
# iteration 600 / 1500: loss 15.051995
# iteration 700 / 1500: loss 12.036845
# iteration 800 / 1500: loss 10.446081
# iteration 900 / 1500: loss 10.326712
# iteration 1000 / 1500: loss 9.071644
# iteration 1100 / 1500: loss 7.688249
# iteration 1200 / 1500: loss 6.836189
# iteration 1300 / 1500: loss 6.663348
# iteration 1400 / 1500: loss 6.526511
# iteration 0 / 1500: loss 83.927590
# iteration 100 / 1500: loss 51.621802
# iteration 200 / 1500: loss 37.401053
# iteration 300 / 1500: loss 28.894950
# iteration 400 / 1500: loss 21.386059
# iteration 500 / 1500: loss 16.798570
# iteration 600 / 1500: loss 13.055062
# iteration 700 / 1500: loss 10.594940
# iteration 800 / 1500: loss 9.336367
# iteration 900 / 1500: loss 7.764303
# iteration 1000 / 1500: loss 7.034134
# iteration 1100 / 1500: loss 6.253820
# iteration 1200 / 1500: loss 6.307087
# iteration 1300 / 1500: loss 5.428657
# iteration 1400 / 1500: loss 5.295728
# iteration 0 / 1500: loss 96.466322
# iteration 100 / 1500: loss 58.352969
# iteration 200 / 1500: loss 39.854994
# iteration 300 / 1500: loss 27.784640
# iteration 400 / 1500: loss 20.402007
# iteration 500 / 1500: loss 14.772707
# iteration 600 / 1500: loss 11.783349
# iteration 700 / 1500: loss 8.878215
# iteration 800 / 1500: loss 7.673803
# iteration 900 / 1500: loss 6.864600
# iteration 1000 / 1500: loss 5.603714
# iteration 1100 / 1500: loss 6.346489
# iteration 1200 / 1500: loss 5.695494
# iteration 1300 / 1500: loss 5.071659
# iteration 1400 / 1500: loss 5.396728
# iteration 0 / 1500: loss 23.703915
# iteration 100 / 1500: loss 9.824255
# iteration 200 / 1500: loss 8.273609
# iteration 300 / 1500: loss 8.091617
# iteration 400 / 1500: loss 6.986630
# iteration 500 / 1500: loss 7.594911
# iteration 600 / 1500: loss 7.171289
# iteration 700 / 1500: loss 7.038006
# iteration 800 / 1500: loss 7.294504
# iteration 900 / 1500: loss 6.263694
# iteration 1000 / 1500: loss 6.659286
# iteration 1100 / 1500: loss 6.392895
# iteration 1200 / 1500: loss 6.620077
# iteration 1300 / 1500: loss 5.806990
# iteration 1400 / 1500: loss 6.281108
# iteration 0 / 1500: loss 24.567143
# iteration 100 / 1500: loss 10.866516
# iteration 200 / 1500: loss 9.510296
# iteration 300 / 1500: loss 9.189736
# iteration 400 / 1500: loss 8.212672
# iteration 500 / 1500: loss 8.793636
# iteration 600 / 1500: loss 8.680545
# iteration 700 / 1500: loss 8.000173
# iteration 800 / 1500: loss 7.642967
# iteration 900 / 1500: loss 9.305907
# iteration 1000 / 1500: loss 7.855450
# iteration 1100 / 1500: loss 7.204109
# iteration 1200 / 1500: loss 7.078478
# iteration 1300 / 1500: loss 8.032028
# iteration 1400 / 1500: loss 6.331243
# iteration 0 / 1500: loss 25.050839
# iteration 100 / 1500: loss 10.406590
# iteration 200 / 1500: loss 10.663404
# iteration 300 / 1500: loss 9.597368
# iteration 400 / 1500: loss 10.668003
# iteration 500 / 1500: loss 9.206767
# iteration 600 / 1500: loss 7.940923
# iteration 700 / 1500: loss 8.216487
# iteration 800 / 1500: loss 7.506542
# iteration 900 / 1500: loss 8.386961
# iteration 1000 / 1500: loss 8.071104
# iteration 1100 / 1500: loss 7.662134
# iteration 1200 / 1500: loss 7.911285
# iteration 1300 / 1500: loss 8.065696
# iteration 1400 / 1500: loss 7.175822
# iteration 0 / 1500: loss 28.716325
# iteration 100 / 1500: loss 13.275828
# iteration 200 / 1500: loss 10.936407
# iteration 300 / 1500: loss 11.494502
# iteration 400 / 1500: loss 10.163175
# iteration 500 / 1500: loss 9.176028
# iteration 600 / 1500: loss 9.394341
# iteration 700 / 1500: loss 9.165445
# iteration 800 / 1500: loss 8.779399
# iteration 900 / 1500: loss 8.422036
# iteration 1000 / 1500: loss 7.939213
# iteration 1100 / 1500: loss 6.972613
# iteration 1200 / 1500: loss 7.323506
# iteration 1300 / 1500: loss 7.937612
# iteration 1400 / 1500: loss 6.890139
# iteration 0 / 1500: loss 26.956089
# iteration 100 / 1500: loss 12.414800
# iteration 200 / 1500: loss 10.788283
# iteration 300 / 1500: loss 10.461935
# iteration 400 / 1500: loss 10.458009
# iteration 500 / 1500: loss 10.822042
# iteration 600 / 1500: loss 9.807638
# iteration 700 / 1500: loss 9.131003
# iteration 800 / 1500: loss 8.917599
# iteration 900 / 1500: loss 9.544206
# iteration 1000 / 1500: loss 9.155241
# iteration 1100 / 1500: loss 7.740936
# iteration 1200 / 1500: loss 8.301469
# iteration 1300 / 1500: loss 7.893877
# iteration 1400 / 1500: loss 8.222092
# iteration 0 / 1500: loss 40.641155
# iteration 100 / 1500: loss 22.132594
# iteration 200 / 1500: loss 19.274680
# iteration 300 / 1500: loss 16.887552
# iteration 400 / 1500: loss 15.078826
# iteration 500 / 1500: loss 14.313348
# iteration 600 / 1500: loss 13.674937
# iteration 700 / 1500: loss 12.176503
# iteration 800 / 1500: loss 11.598179
# iteration 900 / 1500: loss 10.618340
# iteration 1000 / 1500: loss 9.937056
# iteration 1100 / 1500: loss 9.710061
# iteration 1200 / 1500: loss 8.792581
# iteration 1300 / 1500: loss 8.214564
# iteration 1400 / 1500: loss 8.290831
# iteration 0 / 1500: loss 54.774069
# iteration 100 / 1500: loss 32.390820
# iteration 200 / 1500: loss 27.997518
# iteration 300 / 1500: loss 21.526513
# iteration 400 / 1500: loss 19.516633
# iteration 500 / 1500: loss 16.093732
# iteration 600 / 1500: loss 13.698665
# iteration 700 / 1500: loss 11.679517
# iteration 800 / 1500: loss 10.651367
# iteration 900 / 1500: loss 9.362768
# iteration 1000 / 1500: loss 8.675108
# iteration 1100 / 1500: loss 7.724092
# iteration 1200 / 1500: loss 6.909181
# iteration 1300 / 1500: loss 6.521964
# iteration 1400 / 1500: loss 6.527944
# iteration 0 / 1500: loss 71.892176
# iteration 100 / 1500: loss 41.213747
# iteration 200 / 1500: loss 31.383384
# iteration 300 / 1500: loss 24.145664
# iteration 400 / 1500: loss 17.712523
# iteration 500 / 1500: loss 13.973197
# iteration 600 / 1500: loss 11.696504
# iteration 700 / 1500: loss 10.253883
# iteration 800 / 1500: loss 8.386748
# iteration 900 / 1500: loss 7.578661
# iteration 1000 / 1500: loss 6.382396
# iteration 1100 / 1500: loss 6.025389
# iteration 1200 / 1500: loss 6.276906
# iteration 1300 / 1500: loss 5.338564
# iteration 1400 / 1500: loss 5.101403
# iteration 0 / 1500: loss 83.639161
# iteration 100 / 1500: loss 47.586536
# iteration 200 / 1500: loss 33.499569
# iteration 300 / 1500: loss 22.963567
# iteration 400 / 1500: loss 17.361523
# iteration 500 / 1500: loss 12.885090
# iteration 600 / 1500: loss 10.081286
# iteration 700 / 1500: loss 9.118135
# iteration 800 / 1500: loss 6.241518
# iteration 900 / 1500: loss 6.910289
# iteration 1000 / 1500: loss 5.917216
# iteration 1100 / 1500: loss 5.753379
# iteration 1200 / 1500: loss 5.514491
# iteration 1300 / 1500: loss 5.049387
# iteration 1400 / 1500: loss 5.365536
# iteration 0 / 1500: loss 98.027215
# iteration 100 / 1500: loss 51.469925
# iteration 200 / 1500: loss 33.390962
# iteration 300 / 1500: loss 21.748230
# iteration 400 / 1500: loss 14.265839
# iteration 500 / 1500: loss 11.003735
# iteration 600 / 1500: loss 8.416045
# iteration 700 / 1500: loss 6.610662
# iteration 800 / 1500: loss 5.923631
# iteration 900 / 1500: loss 5.821418
# iteration 1000 / 1500: loss 5.299281
# iteration 1100 / 1500: loss 5.261421
# iteration 1200 / 1500: loss 4.522071
# iteration 1300 / 1500: loss 4.792815
# iteration 1400 / 1500: loss 4.466518
# iteration 0 / 1500: loss 23.008478
# iteration 100 / 1500: loss 8.406236
# iteration 200 / 1500: loss 8.671968
# iteration 300 / 1500: loss 7.943563
# iteration 400 / 1500: loss 7.652950
# iteration 500 / 1500: loss 7.773582
# iteration 600 / 1500: loss 7.013900
# iteration 700 / 1500: loss 6.563731
# iteration 800 / 1500: loss 5.980172
# iteration 900 / 1500: loss 5.882581
# iteration 1000 / 1500: loss 6.656884
# iteration 1100 / 1500: loss 6.773088
# iteration 1200 / 1500: loss 5.664212
# iteration 1300 / 1500: loss 6.716731
# iteration 1400 / 1500: loss 6.412995
# iteration 0 / 1500: loss 24.689324
# iteration 100 / 1500: loss 10.836125
# iteration 200 / 1500: loss 9.923634
# iteration 300 / 1500: loss 9.078544
# iteration 400 / 1500: loss 8.991244
# iteration 500 / 1500: loss 8.049294
# iteration 600 / 1500: loss 8.419504
# iteration 700 / 1500: loss 7.654439
# iteration 800 / 1500: loss 6.992809
# iteration 900 / 1500: loss 7.392070
# iteration 1000 / 1500: loss 7.002999
# iteration 1100 / 1500: loss 6.883266
# iteration 1200 / 1500: loss 6.901407
# iteration 1300 / 1500: loss 6.500941
# iteration 1400 / 1500: loss 6.598454
# iteration 0 / 1500: loss 23.604255
# iteration 100 / 1500: loss 11.731201
# iteration 200 / 1500: loss 9.977700
# iteration 300 / 1500: loss 9.749716
# iteration 400 / 1500: loss 8.700616
# iteration 500 / 1500: loss 8.997490
# iteration 600 / 1500: loss 8.606526
# iteration 700 / 1500: loss 8.416848
# iteration 800 / 1500: loss 9.213621
# iteration 900 / 1500: loss 8.335158
# iteration 1000 / 1500: loss 8.027815
# iteration 1100 / 1500: loss 6.689741
# iteration 1200 / 1500: loss 6.995052
# iteration 1300 / 1500: loss 7.665530
# iteration 1400 / 1500: loss 6.794639
# iteration 0 / 1500: loss 24.725788
# iteration 100 / 1500: loss 12.659966
# iteration 200 / 1500: loss 11.458956
# iteration 300 / 1500: loss 9.821063
# iteration 400 / 1500: loss 9.895690
# iteration 500 / 1500: loss 9.915392
# iteration 600 / 1500: loss 9.197635
# iteration 700 / 1500: loss 8.301998
# iteration 800 / 1500: loss 8.963965
# iteration 900 / 1500: loss 7.063774
# iteration 1000 / 1500: loss 8.219193
# iteration 1100 / 1500: loss 7.857740
# iteration 1200 / 1500: loss 8.344407
# iteration 1300 / 1500: loss 7.236073
# iteration 1400 / 1500: loss 7.632175
# iteration 0 / 1500: loss 31.454268
# iteration 100 / 1500: loss 13.857501
# iteration 200 / 1500: loss 11.448350
# iteration 300 / 1500: loss 12.187806
# iteration 400 / 1500: loss 10.913771
# iteration 500 / 1500: loss 9.406927
# iteration 600 / 1500: loss 9.237254
# iteration 700 / 1500: loss 9.443014
# iteration 800 / 1500: loss 9.883317
# iteration 900 / 1500: loss 8.559059
# iteration 1000 / 1500: loss 8.502284
# iteration 1100 / 1500: loss 8.561651
# iteration 1200 / 1500: loss 7.790502
# iteration 1300 / 1500: loss 7.841827
# iteration 1400 / 1500: loss 7.227335
# iteration 0 / 1500: loss 33.910711
# iteration 100 / 1500: loss 19.929718
# iteration 200 / 1500: loss 17.961878
# iteration 300 / 1500: loss 16.186895
# iteration 400 / 1500: loss 14.155463
# iteration 500 / 1500: loss 13.154151
# iteration 600 / 1500: loss 12.018659
# iteration 700 / 1500: loss 11.398820
# iteration 800 / 1500: loss 9.985000
# iteration 900 / 1500: loss 9.986630
# iteration 1000 / 1500: loss 8.825974
# iteration 1100 / 1500: loss 8.770025
# iteration 1200 / 1500: loss 7.455913
# iteration 1300 / 1500: loss 7.375025
# iteration 1400 / 1500: loss 7.404107
# iteration 0 / 1500: loss 53.199243
# iteration 100 / 1500: loss 29.990962
# iteration 200 / 1500: loss 23.975528
# iteration 300 / 1500: loss 19.932146
# iteration 400 / 1500: loss 16.078023
# iteration 500 / 1500: loss 14.425088
# iteration 600 / 1500: loss 12.742528
# iteration 700 / 1500: loss 10.960555
# iteration 800 / 1500: loss 9.099819
# iteration 900 / 1500: loss 8.474974
# iteration 1000 / 1500: loss 7.198606
# iteration 1100 / 1500: loss 7.078620
# iteration 1200 / 1500: loss 6.160794
# iteration 1300 / 1500: loss 6.033468
# iteration 1400 / 1500: loss 5.958419
# iteration 0 / 1500: loss 66.393481
# iteration 100 / 1500: loss 38.357690
# iteration 200 / 1500: loss 27.697904
# iteration 300 / 1500: loss 20.384098
# iteration 400 / 1500: loss 15.382555
# iteration 500 / 1500: loss 12.161969
# iteration 600 / 1500: loss 9.979676
# iteration 700 / 1500: loss 7.869054
# iteration 800 / 1500: loss 7.435124
# iteration 900 / 1500: loss 6.453322
# iteration 1000 / 1500: loss 5.148312
# iteration 1100 / 1500: loss 5.412559
# iteration 1200 / 1500: loss 5.300300
# iteration 1300 / 1500: loss 5.576593
# iteration 1400 / 1500: loss 4.923351
# iteration 0 / 1500: loss 80.103655
# iteration 100 / 1500: loss 43.925837
# iteration 200 / 1500: loss 28.214464
# iteration 300 / 1500: loss 18.435608
# iteration 400 / 1500: loss 13.808771
# iteration 500 / 1500: loss 9.580904
# iteration 600 / 1500: loss 8.729990
# iteration 700 / 1500: loss 6.887422
# iteration 800 / 1500: loss 6.044028
# iteration 900 / 1500: loss 5.326300
# iteration 1000 / 1500: loss 5.568261
# iteration 1100 / 1500: loss 5.411746
# iteration 1200 / 1500: loss 5.062062
# iteration 1300 / 1500: loss 4.834816
# iteration 1400 / 1500: loss 4.994774
# iteration 0 / 1500: loss 95.680267
# iteration 100 / 1500: loss 47.243262
# iteration 200 / 1500: loss 27.424075
# iteration 300 / 1500: loss 17.151100
# iteration 400 / 1500: loss 11.609263
# iteration 500 / 1500: loss 8.636941
# iteration 600 / 1500: loss 6.755066
# iteration 700 / 1500: loss 5.666140
# iteration 800 / 1500: loss 5.786782
# iteration 900 / 1500: loss 5.568109
# iteration 1000 / 1500: loss 5.146930
# iteration 1100 / 1500: loss 5.498133
# iteration 1200 / 1500: loss 5.211045
# iteration 1300 / 1500: loss 4.696865
# iteration 1400 / 1500: loss 4.990574
# iteration 0 / 1500: loss 27.104729
# iteration 100 / 1500: loss 8.803703
# iteration 200 / 1500: loss 8.638381
# iteration 300 / 1500: loss 7.962236
# iteration 400 / 1500: loss 7.593554
# iteration 500 / 1500: loss 7.039658
# iteration 600 / 1500: loss 6.895112
# iteration 700 / 1500: loss 6.911026
# iteration 800 / 1500: loss 7.061318
# iteration 900 / 1500: loss 6.344020
# iteration 1000 / 1500: loss 6.100189
# iteration 1100 / 1500: loss 6.088454
# iteration 1200 / 1500: loss 5.879223
# iteration 1300 / 1500: loss 5.903727
# iteration 1400 / 1500: loss 6.014995
# iteration 0 / 1500: loss 20.831553
# iteration 100 / 1500: loss 10.939408
# iteration 200 / 1500: loss 9.680139
# iteration 300 / 1500: loss 9.021555
# iteration 400 / 1500: loss 7.714716
# iteration 500 / 1500: loss 8.646030
# iteration 600 / 1500: loss 7.799058
# iteration 700 / 1500: loss 7.458678
# iteration 800 / 1500: loss 8.341611
# iteration 900 / 1500: loss 7.844444
# iteration 1000 / 1500: loss 6.405202
# iteration 1100 / 1500: loss 7.231959
# iteration 1200 / 1500: loss 6.027487
# iteration 1300 / 1500: loss 6.622647
# iteration 1400 / 1500: loss 5.928639
# iteration 0 / 1500: loss 26.154156
# iteration 100 / 1500: loss 10.827327
# iteration 200 / 1500: loss 10.126292
# iteration 300 / 1500: loss 9.692572
# iteration 400 / 1500: loss 9.927282
# iteration 500 / 1500: loss 8.810349
# iteration 600 / 1500: loss 7.789411
# iteration 700 / 1500: loss 8.057853
# iteration 800 / 1500: loss 7.859452
# iteration 900 / 1500: loss 6.871262
# iteration 1000 / 1500: loss 7.152793
# iteration 1100 / 1500: loss 7.290309
# iteration 1200 / 1500: loss 7.591949
# iteration 1300 / 1500: loss 7.374265
# iteration 1400 / 1500: loss 6.265494
# iteration 0 / 1500: loss 26.732745
# iteration 100 / 1500: loss 10.421238
# iteration 200 / 1500: loss 10.311005
# iteration 300 / 1500: loss 9.872717
# iteration 400 / 1500: loss 9.312550
# iteration 500 / 1500: loss 8.384275
# iteration 600 / 1500: loss 8.377804
# iteration 700 / 1500: loss 8.573925
# iteration 800 / 1500: loss 7.532860
# iteration 900 / 1500: loss 8.103653
# iteration 1000 / 1500: loss 7.489452
# iteration 1100 / 1500: loss 8.046165
# iteration 1200 / 1500: loss 6.970497
# iteration 1300 / 1500: loss 6.881634
# iteration 1400 / 1500: loss 6.926472
# iteration 0 / 1500: loss 25.268351
# iteration 100 / 1500: loss 12.876095
# iteration 200 / 1500: loss 11.564750
# iteration 300 / 1500: loss 9.906207
# iteration 400 / 1500: loss 9.911243
# iteration 500 / 1500: loss 9.879968
# iteration 600 / 1500: loss 9.175985
# iteration 700 / 1500: loss 8.988751
# iteration 800 / 1500: loss 7.695382
# iteration 900 / 1500: loss 7.899458
# iteration 1000 / 1500: loss 7.349889
# iteration 1100 / 1500: loss 8.258941
# iteration 1200 / 1500: loss 8.117549
# iteration 1300 / 1500: loss 7.684397
# iteration 1400 / 1500: loss 7.540751
# iteration 0 / 1500: loss 41.169609
# iteration 100 / 1500: loss 20.633945
# iteration 200 / 1500: loss 19.027050
# iteration 300 / 1500: loss 15.792105
# iteration 400 / 1500: loss 13.863990
# iteration 500 / 1500: loss 12.458343
# iteration 600 / 1500: loss 11.593039
# iteration 700 / 1500: loss 10.935669
# iteration 800 / 1500: loss 9.466186
# iteration 900 / 1500: loss 8.734904
# iteration 1000 / 1500: loss 7.793498
# iteration 1100 / 1500: loss 7.307418
# iteration 1200 / 1500: loss 7.109104
# iteration 1300 / 1500: loss 6.717655
# iteration 1400 / 1500: loss 5.860319
# iteration 0 / 1500: loss 52.716276
# iteration 100 / 1500: loss 29.377399
# iteration 200 / 1500: loss 22.834489
# iteration 300 / 1500: loss 19.015777
# iteration 400 / 1500: loss 14.533741
# iteration 500 / 1500: loss 12.280193
# iteration 600 / 1500: loss 9.775070
# iteration 700 / 1500: loss 8.084970
# iteration 800 / 1500: loss 8.500130
# iteration 900 / 1500: loss 6.809745
# iteration 1000 / 1500: loss 7.279042
# iteration 1100 / 1500: loss 5.416010
# iteration 1200 / 1500: loss 5.854786
# iteration 1300 / 1500: loss 5.271935
# iteration 1400 / 1500: loss 4.737713
# iteration 0 / 1500: loss 68.390538
# iteration 100 / 1500: loss 36.136382
# iteration 200 / 1500: loss 24.505470
# iteration 300 / 1500: loss 17.353230
# iteration 400 / 1500: loss 13.086342
# iteration 500 / 1500: loss 10.033070
# iteration 600 / 1500: loss 8.346528
# iteration 700 / 1500: loss 7.256358
# iteration 800 / 1500: loss 6.929997
# iteration 900 / 1500: loss 6.279602
# iteration 1000 / 1500: loss 5.816052
# iteration 1100 / 1500: loss 5.510072
# iteration 1200 / 1500: loss 5.284389
# iteration 1300 / 1500: loss 4.780511
# iteration 1400 / 1500: loss 5.487143
# iteration 0 / 1500: loss 84.492439
# iteration 100 / 1500: loss 40.913462
# iteration 200 / 1500: loss 23.903904
# iteration 300 / 1500: loss 15.853676
# iteration 400 / 1500: loss 11.240403
# iteration 500 / 1500: loss 8.315813
# iteration 600 / 1500: loss 6.749574
# iteration 700 / 1500: loss 6.954322
# iteration 800 / 1500: loss 6.168940
# iteration 900 / 1500: loss 6.201718
# iteration 1000 / 1500: loss 5.290318
# iteration 1100 / 1500: loss 5.562936
# iteration 1200 / 1500: loss 4.899127
# iteration 1300 / 1500: loss 5.393954
# iteration 1400 / 1500: loss 5.131114
# iteration 0 / 1500: loss 99.309071
# iteration 100 / 1500: loss 43.365134
# iteration 200 / 1500: loss 23.499787
# iteration 300 / 1500: loss 14.215746
# iteration 400 / 1500: loss 8.979513
# iteration 500 / 1500: loss 6.695906
# iteration 600 / 1500: loss 5.671798
# iteration 700 / 1500: loss 4.966660
# iteration 800 / 1500: loss 4.697486
# iteration 900 / 1500: loss 4.834742
# iteration 1000 / 1500: loss 5.245836
# iteration 1100 / 1500: loss 4.623313
# iteration 1200 / 1500: loss 5.808115
# iteration 1300 / 1500: loss 4.806709
# iteration 1400 / 1500: loss 5.057453
# iteration 0 / 1500: loss 20.780485
# iteration 100 / 1500: loss 10.069000
# iteration 200 / 1500: loss 8.247371
# iteration 300 / 1500: loss 7.310853
# iteration 400 / 1500: loss 7.676769
# iteration 500 / 1500: loss 6.239769
# iteration 600 / 1500: loss 6.955769
# iteration 700 / 1500: loss 6.566707
# iteration 800 / 1500: loss 7.146640
# iteration 900 / 1500: loss 5.828915
# iteration 1000 / 1500: loss 5.893201
# iteration 1100 / 1500: loss 5.805502
# iteration 1200 / 1500: loss 6.840276
# iteration 1300 / 1500: loss 5.951289
# iteration 1400 / 1500: loss 5.281028
# iteration 0 / 1500: loss 28.650101
# iteration 100 / 1500: loss 9.976158
# iteration 200 / 1500: loss 9.287836
# iteration 300 / 1500: loss 9.747509
# iteration 400 / 1500: loss 8.675603
# iteration 500 / 1500: loss 8.561888
# iteration 600 / 1500: loss 7.960030
# iteration 700 / 1500: loss 7.766205
# iteration 800 / 1500: loss 6.315855
# iteration 900 / 1500: loss 7.037784
# iteration 1000 / 1500: loss 6.139998
# iteration 1100 / 1500: loss 7.096984
# iteration 1200 / 1500: loss 6.467187
# iteration 1300 / 1500: loss 6.607032
# iteration 1400 / 1500: loss 6.480128
# iteration 0 / 1500: loss 28.507864
# iteration 100 / 1500: loss 9.560792
# iteration 200 / 1500: loss 8.862967
# iteration 300 / 1500: loss 9.380326
# iteration 400 / 1500: loss 9.112769
# iteration 500 / 1500: loss 8.500987
# iteration 600 / 1500: loss 8.553840
# iteration 700 / 1500: loss 7.211665
# iteration 800 / 1500: loss 7.398354
# iteration 900 / 1500: loss 8.196143
# iteration 1000 / 1500: loss 7.741050
# iteration 1100 / 1500: loss 6.949377
# iteration 1200 / 1500: loss 6.695874
# iteration 1300 / 1500: loss 6.408413
# iteration 1400 / 1500: loss 7.287355
# iteration 0 / 1500: loss 27.700555
# iteration 100 / 1500: loss 11.294413
# iteration 200 / 1500: loss 11.019429
# iteration 300 / 1500: loss 10.453291
# iteration 400 / 1500: loss 8.412543
# iteration 500 / 1500: loss 9.359003
# iteration 600 / 1500: loss 8.409329
# iteration 700 / 1500: loss 7.855637
# iteration 800 / 1500: loss 7.552330
# iteration 900 / 1500: loss 8.399610
# iteration 1000 / 1500: loss 7.557751
# iteration 1100 / 1500: loss 7.639608
# iteration 1200 / 1500: loss 7.243912
# iteration 1300 / 1500: loss 6.930051
# iteration 1400 / 1500: loss 7.209933
# iteration 0 / 1500: loss 30.902436
# iteration 100 / 1500: loss 12.063913
# iteration 200 / 1500: loss 10.792226
# iteration 300 / 1500: loss 10.824669
# iteration 400 / 1500: loss 9.445350
# iteration 500 / 1500: loss 9.688003
# iteration 600 / 1500: loss 9.129554
# iteration 700 / 1500: loss 9.055004
# iteration 800 / 1500: loss 8.034284
# iteration 900 / 1500: loss 8.408523
# iteration 1000 / 1500: loss 7.801406
# iteration 1100 / 1500: loss 7.111545
# iteration 1200 / 1500: loss 7.641297
# iteration 1300 / 1500: loss 7.282028
# iteration 1400 / 1500: loss 6.814228
# iteration 0 / 1500: loss 36.909095
# iteration 100 / 1500: loss 20.141871
# iteration 200 / 1500: loss 16.776208
# iteration 300 / 1500: loss 14.577665
# iteration 400 / 1500: loss 12.880151
# iteration 500 / 1500: loss 12.035925
# iteration 600 / 1500: loss 10.393786
# iteration 700 / 1500: loss 9.738785
# iteration 800 / 1500: loss 8.500547
# iteration 900 / 1500: loss 7.905519
# iteration 1000 / 1500: loss 7.775502
# iteration 1100 / 1500: loss 6.935073
# iteration 1200 / 1500: loss 6.973201
# iteration 1300 / 1500: loss 5.791350
# iteration 1400 / 1500: loss 6.027662
# iteration 0 / 1500: loss 49.542159
# iteration 100 / 1500: loss 28.599713
# iteration 200 / 1500: loss 21.511562
# iteration 300 / 1500: loss 16.622438
# iteration 400 / 1500: loss 14.137700
# iteration 500 / 1500: loss 11.356544
# iteration 600 / 1500: loss 9.157551
# iteration 700 / 1500: loss 8.010544
# iteration 800 / 1500: loss 7.642902
# iteration 900 / 1500: loss 7.049670
# iteration 1000 / 1500: loss 5.952633
# iteration 1100 / 1500: loss 5.486775
# iteration 1200 / 1500: loss 6.343479
# iteration 1300 / 1500: loss 4.689367
# iteration 1400 / 1500: loss 5.069227
# iteration 0 / 1500: loss 66.778717
# iteration 100 / 1500: loss 34.557680
# ...
# iteration 300 / 1500: loss 14.089891
# iteration 400 / 1500: loss 10.148892
# iteration 500 / 1500: loss 7.478934
# iteration 600 / 1500: loss 7.045920
# iteration 700 / 1500: loss 5.824085
# iteration 800 / 1500: loss 5.173529
# iteration 900 / 1500: loss 5.672349
# iteration 1000 / 1500: loss 5.479944
# iteration 1100 / 1500: loss 5.031844
# iteration 1200 / 1500: loss 5.634594
# iteration 1300 / 1500: loss 4.787399
# iteration 1400 / 1500: loss 4.890930
# iteration 0 / 1500: loss 83.008124
# iteration 100 / 1500: loss 34.290619
# iteration 200 / 1500: loss 19.634866
# iteration 300 / 1500: loss 11.579492
# iteration 400 / 1500: loss 8.820010
# iteration 500 / 1500: loss 6.569480
# iteration 600 / 1500: loss 6.249348
# iteration 700 / 1500: loss 4.878228
# iteration 800 / 1500: loss 5.983036
# iteration 900 / 1500: loss 5.162094
# iteration 1000 / 1500: loss 5.271806
# iteration 1100 / 1500: loss 5.688202
# iteration 1200 / 1500: loss 4.584644
# iteration 1300 / 1500: loss 5.109268
# iteration 1400 / 1500: loss 4.933879
# iteration 0 / 1500: loss 95.611243
# iteration 100 / 1500: loss 36.002274
# iteration 200 / 1500: loss 17.689075
# iteration 300 / 1500: loss 9.713857
# iteration 400 / 1500: loss 7.372218
# iteration 500 / 1500: loss 7.167836
# iteration 600 / 1500: loss 6.416643
# iteration 700 / 1500: loss 5.664242
# iteration 800 / 1500: loss 5.004178
# iteration 900 / 1500: loss 5.558341
# iteration 1000 / 1500: loss 5.435841
# iteration 1100 / 1500: loss 4.807847
# iteration 1200 / 1500: loss 6.474998
# iteration 1300 / 1500: loss 5.246312
# iteration 1400 / 1500: loss 5.754878
# iteration 0 / 1500: loss 23.970547
# iteration 100 / 1500: loss 7.745966
# iteration 200 / 1500: loss 7.817847
# iteration 300 / 1500: loss 7.220216
# iteration 400 / 1500: loss 6.763618
# iteration 500 / 1500: loss 6.817752
# iteration 600 / 1500: loss 6.976053
# iteration 700 / 1500: loss 6.323779
# iteration 800 / 1500: loss 6.576608
# iteration 900 / 1500: loss 6.047035
# iteration 1000 / 1500: loss 5.532663
# iteration 1100 / 1500: loss 5.107005
# iteration 1200 / 1500: loss 6.809524
# iteration 1300 / 1500: loss 5.137794
# iteration 1400 / 1500: loss 6.222679
# iteration 0 / 1500: loss 26.307690
# iteration 100 / 1500: loss 10.380315
# iteration 200 / 1500: loss 9.305617
# iteration 300 / 1500: loss 9.181894
# iteration 400 / 1500: loss 8.063710
# iteration 500 / 1500: loss 7.948059
# iteration 600 / 1500: loss 7.145898
# iteration 700 / 1500: loss 6.742945
# iteration 800 / 1500: loss 7.374957
# iteration 900 / 1500: loss 6.559451
# iteration 1000 / 1500: loss 7.415117
# iteration 1100 / 1500: loss 6.597700
# iteration 1200 / 1500: loss 7.546245
# iteration 1300 / 1500: loss 6.300087
# iteration 1400 / 1500: loss 6.572486
# iteration 0 / 1500: loss 26.165191
# iteration 100 / 1500: loss 11.180114
# iteration 200 / 1500: loss 8.300650
# iteration 300 / 1500: loss 9.358732
# iteration 400 / 1500: loss 8.668132
# iteration 500 / 1500: loss 9.005425
# iteration 600 / 1500: loss 6.956127
# iteration 700 / 1500: loss 8.530196
# iteration 800 / 1500: loss 7.320179
# iteration 900 / 1500: loss 8.643345
# iteration 1000 / 1500: loss 6.815046
# iteration 1100 / 1500: loss 7.215038
# iteration 1200 / 1500: loss 6.916181
# iteration 1300 / 1500: loss 7.042805
# iteration 1400 / 1500: loss 6.242548
# iteration 0 / 1500: loss 28.153372
# iteration 100 / 1500: loss 10.710732
# iteration 200 / 1500: loss 10.076335
# iteration 300 / 1500: loss 10.092702
# iteration 400 / 1500: loss 8.950330
# iteration 500 / 1500: loss 8.176685
# iteration 600 / 1500: loss 8.144423
# iteration 700 / 1500: loss 7.487335
# iteration 800 / 1500: loss 8.085744
# iteration 900 / 1500: loss 7.656987
# iteration 1000 / 1500: loss 7.920007
# iteration 1100 / 1500: loss 6.527026
# iteration 1200 / 1500: loss 6.680130
# iteration 1300 / 1500: loss 6.721265
# iteration 1400 / 1500: loss 6.976948
# iteration 0 / 1500: loss 22.019487
# iteration 100 / 1500: loss 12.664619
# iteration 200 / 1500: loss 11.494874
# iteration 300 / 1500: loss 10.876408
# iteration 400 / 1500: loss 10.336949
# iteration 500 / 1500: loss 8.799522
# iteration 600 / 1500: loss 8.322353
# iteration 700 / 1500: loss 7.335879
# iteration 800 / 1500: loss 7.501002
# iteration 900 / 1500: loss 7.647194
# iteration 1000 / 1500: loss 7.757384
# iteration 1100 / 1500: loss 7.175775
# iteration 1200 / 1500: loss 7.755674
# iteration 1300 / 1500: loss 5.915184
# iteration 1400 / 1500: loss 6.123121
# iteration 0 / 1500: loss 37.060161
# iteration 100 / 1500: loss 18.662448
# iteration 200 / 1500: loss 16.563978
# iteration 300 / 1500: loss 13.272349
# iteration 400 / 1500: loss 11.712799
# iteration 500 / 1500: loss 10.172071
# iteration 600 / 1500: loss 10.153279
# iteration 700 / 1500: loss 8.514328
# iteration 800 / 1500: loss 8.527635
# iteration 900 / 1500: loss 7.668860
# iteration 1000 / 1500: loss 7.285830
# iteration 1100 / 1500: loss 5.894071
# iteration 1200 / 1500: loss 6.352946
# iteration 1300 / 1500: loss 5.212864
# iteration 1400 / 1500: loss 5.890978
# iteration 0 / 1500: loss 52.396527
# iteration 100 / 1500: loss 25.402066
# iteration 200 / 1500: loss 19.359822
# iteration 300 / 1500: loss 14.070286
# iteration 400 / 1500: loss 10.435838
# iteration 500 / 1500: loss 8.990619
# iteration 600 / 1500: loss 7.394213
# iteration 700 / 1500: loss 7.265269
# iteration 800 / 1500: loss 6.270788
# iteration 900 / 1500: loss 5.817147
# iteration 1000 / 1500: loss 6.240655
# iteration 1100 / 1500: loss 5.790264
# iteration 1200 / 1500: loss 5.257537
# iteration 1300 / 1500: loss 6.623987
# iteration 1400 / 1500: loss 5.785330
# iteration 0 / 1500: loss 73.633112
# iteration 100 / 1500: loss 30.132146
# iteration 200 / 1500: loss 19.263926
# iteration 300 / 1500: loss 12.158501
# iteration 400 / 1500: loss 8.662983
# iteration 500 / 1500: loss 7.355452
# iteration 600 / 1500: loss 6.418133
# iteration 700 / 1500: loss 5.711707
# iteration 800 / 1500: loss 5.944192
# iteration 900 / 1500: loss 5.768240
# iteration 1000 / 1500: loss 5.476995
# iteration 1100 / 1500: loss 5.440216
# iteration 1200 / 1500: loss 4.956308
# iteration 1300 / 1500: loss 5.227389
# iteration 1400 / 1500: loss 4.630671
# iteration 0 / 1500: loss 85.689111
# iteration 100 / 1500: loss 32.728077
# iteration 200 / 1500: loss 16.639450
# iteration 300 / 1500: loss 10.901010
# iteration 400 / 1500: loss 6.914138
# iteration 500 / 1500: loss 5.694342
# iteration 600 / 1500: loss 5.993082
# iteration 700 / 1500: loss 5.850726
# iteration 800 / 1500: loss 5.297577
# iteration 900 / 1500: loss 5.134871
# iteration 1000 / 1500: loss 5.646670
# iteration 1100 / 1500: loss 6.338795
# iteration 1200 / 1500: loss 4.932040
# iteration 1300 / 1500: loss 5.692713
# iteration 1400 / 1500: loss 5.752609
# iteration 0 / 1500: loss 100.668348
# iteration 100 / 1500: loss 33.256165
# iteration 200 / 1500: loss 15.269786
# iteration 300 / 1500: loss 9.705887
# iteration 400 / 1500: loss 7.070308
# iteration 500 / 1500: loss 6.470598
# iteration 600 / 1500: loss 5.591593
# iteration 700 / 1500: loss 5.736221
# iteration 800 / 1500: loss 5.420859
# iteration 900 / 1500: loss 5.770679
# iteration 1000 / 1500: loss 5.228211
# iteration 1100 / 1500: loss 4.463560
# iteration 1200 / 1500: loss 4.936468
# iteration 1300 / 1500: loss 5.091448
# iteration 1400 / 1500: loss 5.546401
# lr 1.000000e-07 reg 1.000000e+02 train accuracy: 0.304020 val accuracy: 0.307000
# lr 1.000000e-07 reg 2.000000e+02 train accuracy: 0.308347 val accuracy: 0.307000
# lr 1.000000e-07 reg 2.500000e+02 train accuracy: 0.308429 val accuracy: 0.325000
# lr 1.000000e-07 reg 3.000000e+02 train accuracy: 0.305265 val accuracy: 0.294000
# lr 1.000000e-07 reg 3.500000e+02 train accuracy: 0.308571 val accuracy: 0.314000
# lr 1.000000e-07 reg 1.000000e+03 train accuracy: 0.311755 val accuracy: 0.321000
# lr 1.000000e-07 reg 2.000000e+03 train accuracy: 0.316184 val accuracy: 0.320000
# lr 1.000000e-07 reg 3.000000e+03 train accuracy: 0.325735 val accuracy: 0.338000
# lr 1.000000e-07 reg 4.000000e+03 train accuracy: 0.335020 val accuracy: 0.332000
# lr 1.000000e-07 reg 5.000000e+03 train accuracy: 0.347143 val accuracy: 0.350000
# lr 2.000000e-07 reg 1.000000e+02 train accuracy: 0.327286 val accuracy: 0.321000
# lr 2.000000e-07 reg 2.000000e+02 train accuracy: 0.328694 val accuracy: 0.315000
# lr 2.000000e-07 reg 2.500000e+02 train accuracy: 0.329633 val accuracy: 0.318000
# lr 2.000000e-07 reg 3.000000e+02 train accuracy: 0.330469 val accuracy: 0.336000
# lr 2.000000e-07 reg 3.500000e+02 train accuracy: 0.320061 val accuracy: 0.337000
# lr 2.000000e-07 reg 1.000000e+03 train accuracy: 0.343694 val accuracy: 0.349000
# lr 2.000000e-07 reg 2.000000e+03 train accuracy: 0.357714 val accuracy: 0.344000
# lr 2.000000e-07 reg 3.000000e+03 train accuracy: 0.371367 val accuracy: 0.386000
# lr 2.000000e-07 reg 4.000000e+03 train accuracy: 0.380980 val accuracy: 0.372000
# lr 2.000000e-07 reg 5.000000e+03 train accuracy: 0.381980 val accuracy: 0.399000
# lr 2.500000e-07 reg 1.000000e+02 train accuracy: 0.337143 val accuracy: 0.352000
# lr 2.500000e-07 reg 2.000000e+02 train accuracy: 0.341367 val accuracy: 0.351000
# lr 2.500000e-07 reg 2.500000e+02 train accuracy: 0.337163 val accuracy: 0.344000
# lr 2.500000e-07 reg 3.000000e+02 train accuracy: 0.340673 val accuracy: 0.333000
# lr 2.500000e-07 reg 3.500000e+02 train accuracy: 0.340000 val accuracy: 0.351000
# lr 2.500000e-07 reg 1.000000e+03 train accuracy: 0.352633 val accuracy: 0.354000
# lr 2.500000e-07 reg 2.000000e+03 train accuracy: 0.374408 val accuracy: 0.379000
# lr 2.500000e-07 reg 3.000000e+03 train accuracy: 0.379327 val accuracy: 0.373000
# lr 2.500000e-07 reg 4.000000e+03 train accuracy: 0.394102 val accuracy: 0.386000
# lr 2.500000e-07 reg 5.000000e+03 train accuracy: 0.387592 val accuracy: 0.398000
# lr 3.000000e-07 reg 1.000000e+02 train accuracy: 0.340347 val accuracy: 0.351000
# lr 3.000000e-07 reg 2.000000e+02 train accuracy: 0.339571 val accuracy: 0.336000
# lr 3.000000e-07 reg 2.500000e+02 train accuracy: 0.341551 val accuracy: 0.350000
# lr 3.000000e-07 reg 3.000000e+02 train accuracy: 0.351959 val accuracy: 0.313000
# lr 3.000000e-07 reg 3.500000e+02 train accuracy: 0.356469 val accuracy: 0.329000
# lr 3.000000e-07 reg 1.000000e+03 train accuracy: 0.362837 val accuracy: 0.350000
# lr 3.000000e-07 reg 2.000000e+03 train accuracy: 0.379184 val accuracy: 0.391000
# lr 3.000000e-07 reg 3.000000e+03 train accuracy: 0.386224 val accuracy: 0.387000
# lr 3.000000e-07 reg 4.000000e+03 train accuracy: 0.388102 val accuracy: 0.370000
# lr 3.000000e-07 reg 5.000000e+03 train accuracy: 0.389265 val accuracy: 0.378000
# lr 4.000000e-07 reg 1.000000e+02 train accuracy: 0.350694 val accuracy: 0.368000
# lr 4.000000e-07 reg 2.000000e+02 train accuracy: 0.363388 val accuracy: 0.363000
# lr 4.000000e-07 reg 2.500000e+02 train accuracy: 0.356735 val accuracy: 0.352000
# lr 4.000000e-07 reg 3.000000e+02 train accuracy: 0.352837 val accuracy: 0.337000
# lr 4.000000e-07 reg 3.500000e+02 train accuracy: 0.354918 val accuracy: 0.347000
# lr 4.000000e-07 reg 1.000000e+03 train accuracy: 0.377980 val accuracy: 0.376000
# lr 4.000000e-07 reg 2.000000e+03 train accuracy: 0.388878 val accuracy: 0.375000
# lr 4.000000e-07 reg 3.000000e+03 train accuracy: 0.374327 val accuracy: 0.376000
# lr 4.000000e-07 reg 4.000000e+03 train accuracy: 0.386388 val accuracy: 0.387000
# lr 4.000000e-07 reg 5.000000e+03 train accuracy: 0.388245 val accuracy: 0.397000
# lr 5.000000e-07 reg 1.000000e+02 train accuracy: 0.357408 val accuracy: 0.371000
# lr 5.000000e-07 reg 2.000000e+02 train accuracy: 0.355857 val accuracy: 0.331000
# lr 5.000000e-07 reg 2.500000e+02 train accuracy: 0.363714 val accuracy: 0.357000
# lr 5.000000e-07 reg 3.000000e+02 train accuracy: 0.358449 val accuracy: 0.351000
# lr 5.000000e-07 reg 3.500000e+02 train accuracy: 0.365449 val accuracy: 0.368000
# lr 5.000000e-07 reg 1.000000e+03 train accuracy: 0.378755 val accuracy: 0.368000
# lr 5.000000e-07 reg 2.000000e+03 train accuracy: 0.385980 val accuracy: 0.362000
# lr 5.000000e-07 reg 3.000000e+03 train accuracy: 0.379286 val accuracy: 0.373000
# lr 5.000000e-07 reg 4.000000e+03 train accuracy: 0.396673 val accuracy: 0.402000
# lr 5.000000e-07 reg 5.000000e+03 train accuracy: 0.382286 val accuracy: 0.384000
# lr 6.000000e-07 reg 1.000000e+02 train accuracy: 0.357388 val accuracy: 0.352000
# lr 6.000000e-07 reg 2.000000e+02 train accuracy: 0.371755 val accuracy: 0.360000
# lr 6.000000e-07 reg 2.500000e+02 train accuracy: 0.368510 val accuracy: 0.363000
# lr 6.000000e-07 reg 3.000000e+02 train accuracy: 0.365184 val accuracy: 0.375000
# lr 6.000000e-07 reg 3.500000e+02 train accuracy: 0.367082 val accuracy: 0.380000
# lr 6.000000e-07 reg 1.000000e+03 train accuracy: 0.386837 val accuracy: 0.369000
# lr 6.000000e-07 reg 2.000000e+03 train accuracy: 0.370163 val accuracy: 0.370000
# lr 6.000000e-07 reg 3.000000e+03 train accuracy: 0.380653 val accuracy: 0.376000
# lr 6.000000e-07 reg 4.000000e+03 train accuracy: 0.380245 val accuracy: 0.374000
# lr 6.000000e-07 reg 5.000000e+03 train accuracy: 0.370408 val accuracy: 0.370000
# lr 7.000000e-07 reg 1.000000e+02 train accuracy: 0.369449 val accuracy: 0.381000
# lr 7.000000e-07 reg 2.000000e+02 train accuracy: 0.367878 val accuracy: 0.378000
# lr 7.000000e-07 reg 2.500000e+02 train accuracy: 0.377878 val accuracy: 0.345000
# lr 7.000000e-07 reg 3.000000e+02 train accuracy: 0.376633 val accuracy: 0.372000
# lr 7.000000e-07 reg 3.500000e+02 train accuracy: 0.362184 val accuracy: 0.365000
# lr 7.000000e-07 reg 1.000000e+03 train accuracy: 0.376102 val accuracy: 0.372000
# lr 7.000000e-07 reg 2.000000e+03 train accuracy: 0.386490 val accuracy: 0.380000
# lr 7.000000e-07 reg 3.000000e+03 train accuracy: 0.378429 val accuracy: 0.369000
# lr 7.000000e-07 reg 4.000000e+03 train accuracy: 0.374102 val accuracy: 0.398000
# lr 7.000000e-07 reg 5.000000e+03 train accuracy: 0.358510 val accuracy: 0.353000
# lr 8.000000e-07 reg 1.000000e+02 train accuracy: 0.376102 val accuracy: 0.376000
# lr 8.000000e-07 reg 2.000000e+02 train accuracy: 0.371694 val accuracy: 0.371000
# lr 8.000000e-07 reg 2.500000e+02 train accuracy: 0.374408 val accuracy: 0.361000
# lr 8.000000e-07 reg 3.000000e+02 train accuracy: 0.371204 val accuracy: 0.358000
# lr 8.000000e-07 reg 3.500000e+02 train accuracy: 0.373939 val accuracy: 0.356000
# lr 8.000000e-07 reg 1.000000e+03 train accuracy: 0.361816 val accuracy: 0.372000
# lr 8.000000e-07 reg 2.000000e+03 train accuracy: 0.370510 val accuracy: 0.377000
# lr 8.000000e-07 reg 3.000000e+03 train accuracy: 0.378694 val accuracy: 0.370000
# lr 8.000000e-07 reg 4.000000e+03 train accuracy: 0.339204 val accuracy: 0.314000
# lr 8.000000e-07 reg 5.000000e+03 train accuracy: 0.364061 val accuracy: 0.356000
# lr 9.000000e-07 reg 1.000000e+02 train accuracy: 0.378367 val accuracy: 0.377000
# lr 9.000000e-07 reg 2.000000e+02 train accuracy: 0.369306 val accuracy: 0.358000
# lr 9.000000e-07 reg 2.500000e+02 train accuracy: 0.357367 val accuracy: 0.351000
# lr 9.000000e-07 reg 3.000000e+02 train accuracy: 0.378735 val accuracy: 0.360000
# lr 9.000000e-07 reg 3.500000e+02 train accuracy: 0.361571 val accuracy: 0.354000
# lr 9.000000e-07 reg 1.000000e+03 train accuracy: 0.370551 val accuracy: 0.365000
# lr 9.000000e-07 reg 2.000000e+03 train accuracy: 0.360347 val accuracy: 0.353000
# lr 9.000000e-07 reg 3.000000e+03 train accuracy: 0.358000 val accuracy: 0.355000
# lr 9.000000e-07 reg 4.000000e+03 train accuracy: 0.368755 val accuracy: 0.361000
# lr 9.000000e-07 reg 5.000000e+03 train accuracy: 0.353939 val accuracy: 0.342000
# lr 1.000000e-06 reg 1.000000e+02 train accuracy: 0.359306 val accuracy: 0.369000
# lr 1.000000e-06 reg 2.000000e+02 train accuracy: 0.377531 val accuracy: 0.381000
# lr 1.000000e-06 reg 2.500000e+02 train accuracy: 0.358673 val accuracy: 0.341000
# lr 1.000000e-06 reg 3.000000e+02 train accuracy: 0.372816 val accuracy: 0.363000
# lr 1.000000e-06 reg 3.500000e+02 train accuracy: 0.378673 val accuracy: 0.376000
# lr 1.000000e-06 reg 1.000000e+03 train accuracy: 0.374857 val accuracy: 0.378000
# lr 1.000000e-06 reg 2.000000e+03 train accuracy: 0.360000 val accuracy: 0.367000
# lr 1.000000e-06 reg 3.000000e+03 train accuracy: 0.338592 val accuracy: 0.327000
# lr 1.000000e-06 reg 4.000000e+03 train accuracy: 0.341020 val accuracy: 0.356000
# lr 1.000000e-06 reg 5.000000e+03 train accuracy: 0.352714 val accuracy: 0.356000
# best validation accuracy achieved during cross-validation: 0.402000

# %%
# Visualize the cross-validation results
import math
x_scatter = [math.log10(x[0]) for x in results]
y_scatter = [math.log10(x[1]) for x in results]

# plot training accuracy
marker_size = 100
colors = [results[x][0] for x in results]
plt.subplot(2, 1, 1)
plt.scatter(x_scatter, y_scatter, marker_size, c=colors)
plt.colorbar()
plt.xlabel('log learning rate')
plt.ylabel('log regularization strength')
plt.title('CIFAR-10 training accuracy')

# plot validation accuracy
colors = [results[x][1] for x in results] # default size of markers is 20
plt.subplot(2, 1, 2)
plt.scatter(x_scatter, y_scatter, marker_size, c=colors)
plt.colorbar()
plt.xlabel('log learning rate')
plt.ylabel('log regularization strength')
plt.title('CIFAR-10 validation accuracy')
plt.show()

# %%
# Evaluate the best svm on test set
y_test_pred = best_svm.predict(X_test)
test_accuracy = np.mean(y_test == y_test_pred)
print('linear SVM on raw pixels final test set accuracy: %f' % test_accuracy)
# Out:
# linear SVM on raw pixels final test set accuracy: 0.383000

# %%
# Visualize the learned weights for each class.
# Depending on your choice of learning rate and regularization strength, these may
# or may not be nice to look at.
w = best_svm.W[:-1,:] # strip out the bias
w = w.reshape(32, 32, 3, 10)
w_min, w_max = np.min(w), np.max(w)
classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
for i in range(10):
    plt.subplot(2, 5, i + 1)
      
    # Rescale the weights to be between 0 and 255
    wimg = 255.0 * (w[:, :, :, i].squeeze() - w_min) / (w_max - w_min)
    plt.imshow(wimg.astype('uint8'))
    plt.axis('off')
    plt.title(classes[i])

# %% [markdown]
# ### Inline question 2:
# Describe what your visualized SVM weights look like, and offer a brief explanation for why they look they way that they do.
#
# **Your answer:** *fill this in*
